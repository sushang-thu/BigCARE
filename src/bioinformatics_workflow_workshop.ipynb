# %% [markdown]
# <a href="https://colab.research.google.com/github/sushang-thu/BigCARE/blob/main/src/bioinformatics_workflow_workshop.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # FAIR principles applied to cancer bioinformatics workflows

# %% [markdown]
# ## Introduction
# In this workshop, we will be
# - Discuss how to apply the FAIR principles to bioinformatics workflows
# - installing the conda package manager
# - installing the nextflow workflow manager and bioinformatics tools
# - search and download data from the cloud
# - running the nextflow pipeline
# - examine the results

# %% [markdown]
# ### The FAIR principles - Findable, Accessible, Interoperable, and Reusable
# These principles help ensure that data, tools, and methodologies are easily discoverable and usable by both humans and machines.

# %% [markdown]
# ### Findable
# - It is recommended that researchers share their code and workflows on version control and collaboration platforms, such as Github and Gitlab
# - Provide persistent links: Each file and commit in a GitHub repository has a unique URL, providing stable, long-term access to specific versions of a workflow.
#   - [Zenodo](https://zenodo.org/): Specifically designed for researchers, it provides DOIs for code, making it easier to cite in academic publications.
#   - Dataverse: An open-source platform for sharing, preserving, and analyzing research data, including code, e.g. [Harvard Dataverse](https://dataverse.harvard.edu/).
# - Discoverability: Include metadata to improve the chances of workflows being found by interested researchers.

# %% [markdown]
# ### Accessible
#
# -  Access: GitHub provides a public platform where researchers can freely share their code, making it accessible to anyone with an internet connection.
# - Version control: GitHub's version control system allows users to access different versions of a workflow, including the latest updates and previous iterations (e.g. the version used for publication).
# - Documentation: README files, wikis, and inline comments in GitHub repositories can provide clear instructions on how to access and use the workflows.
# - Issue tracking: The issue tracker on GitHub allows users to report problems or request features, facilitating communication between creators and users of the workflow.
# - API access: GitHub's API allows programmatic access to repositories, enabling automated systems to retrieve workflows.

# %% [markdown]
# ### Interoperability
# - Vital in cancer bioinformatics workflows, as it enables the integration of diverse data types and tools from various sources.
# - By adhering to standard formats, providing detailed documentation, and using common ontologies, researchers can create workflows that others can easily adapt and build upon
# - Portable, can be run on different computational systems

# %% [markdown]
# ### Reusability
#
# - Portable and consistent computational environment ensuring identical results across diverse systems
# - Clear documentation
# - Observability provides crucial insights into the execution, performance, and behavior of bioinformatics pipelines, enabling other researchers to understand, reproduce, and adapt the workflows effectively.
#   - By incorporating comprehensive logging, performance metrics, and execution traces, observability enhances the transparency and reliability of workflows, making them more reusable across different environments and research contexts.
#   - Monitoring and logging provide crucial information that allows others to understand how a workflow was executed, what resources were used, and what issues (if any) were encountered.

# %% [markdown]
# ### Web-based collaborative development platforms
#
# - [GitHub.com](https://github.com/), [Gitlab.com](https://about.gitlab.com/)
# - Version control source code, allowing for easy tracking of changes and rollbacks if needed.
# - Share workflows openly, enabling other researchers to examine, use, and build upon existing work.
# - Facilitate collaboration through features like pull requests and issue tracking.
# - Provide documentation alongside the code, improving understanding and reproducibility.

# %% [markdown]
# ### Workflow management systems
#
# - Offering a standardized way to define and execute complex bioinformatics pipelines.
# - Providing built-in support for containerization (e.g., Docker, Singularity) and conda environments, allowing environment specifications to be included directly in the workflow definition, ensuring consistent environments across different systems.
# - Supporting modular design, allowing researchers to easily swap out or update individual steps in a pipeline.
# - Automatically handling job scheduling and parallelization, making workflows more efficient and scalable.

# %% [markdown]
# ### Open source collection of workflows and workflow mangement systems:
# - Nextflow provides [nf-core](https://nf-co.re/)
# - Snakemake provides [Snakemake workflow catalog](https://snakemake.github.io/snakemake-workflow-catalog/)
# - https://workflowhub.eu/
# - Many others: https://github.com/common-workflow-language/common-workflow-language/wiki/Existing-Workflow-systems

# %% [markdown]
# ## Hands on workshop

# %% [markdown]
# ![Example Sarke workflow](https://raw.githubusercontent.com/nf-core/sarek/3.4.2//docs/images/sarek_subway.png)

# %% [markdown]
# ### Install conda package manager
#
# Conda is a cross-platform package management system and environment manager primarily used for Python programming, allowing users to easily install, run, and update packages and their dependencies.

# %%
import os

conda_path = "/usr/local/bin/conda"

if os.path.exists(conda_path):
    print(f"{conda_path} exists.")
else:
    print(f"{conda_path} does not exist, installing")
    # !pip install -q condacolab
    import condacolab
    condacolab.install()
# Out:
# /usr/local/bin/conda does not exist, installing
# ⏬ Downloading https://github.com/conda-forge/miniforge/releases/download/23.11.0-0/Mambaforge-23.11.0-0-Linux-x86_64.sh...
# 📦 Installing...
# 📌 Adjusting configuration...
# 🩹 Patching environment...
# ⏲ Done in 0:00:17
# 🔁 Restarting kernel...

# %%
# !conda --version
# Out:
# conda 23.11.0

# %% [markdown]
# ### Use conda to install tools
# - Conda channels are repositories that contain packages for installation.
# - One notable channel in the bioinformatics community is Bioconda, which specializes in providing bioinformatics software.
# - Bioconda offers a vast array of tools and libraries specifically tailored for biological data analysis, making it easier for researchers to set up and manage their computational environments.
# - We will install Nextflow and Samtools through Bioconda.
#   - [Nextflow](https://www.nextflow.io/) is a powerful workflow management system that enables scalable and reproducible scientific workflows using software containers.
#   - [Samtools](https://www.htslib.org/) is a suite of programs for interacting with high-throughput sequencing data. It provides various utilities for manipulating alignments in the SAM format, including sorting, merging, indexing, and generating alignments in various formats.

# %%
# %%bash
# conda config --add channels bioconda
# conda config --add channels conda-forge
# conda install samtools=1.20 nextflow=24.04.3 -y
# Out:
# Channels:
#  - conda-forge
#  - bioconda
# Platform: linux-64
# Collecting package metadata (repodata.json): ...working... done
# Solving environment: ...working... done
#
# ## Package Plan ##
#
#   environment location: /usr/local
#
#   added / updated specs:
#     - nextflow=24.04.3
#     - samtools=1.20
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     alsa-lib-1.2.12            |       h4ab18f5_0         543 KB  conda-forge
#     ca-certificates-2024.7.4   |       hbcca054_0         151 KB  conda-forge
#     cairo-1.18.0               |       h3faef2a_0         959 KB  conda-forge
#     certifi-2024.7.4           |     pyhd8ed1ab_0         156 KB  conda-forge
#     coreutils-9.5              |       hd590300_0         2.9 MB  conda-forge
#     curl-8.8.0                 |       he654da7_0         163 KB  conda-forge
#     expat-2.6.2                |       h59595ed_0         134 KB  conda-forge
#     font-ttf-dejavu-sans-mono-2.37|       hab24e00_0         388 KB  conda-forge
#     font-ttf-inconsolata-3.000 |       h77eed37_0          94 KB  conda-forge
#     font-ttf-source-code-pro-2.038|       h77eed37_0         684 KB  conda-forge
#     font-ttf-ubuntu-0.83       |       h77eed37_2         1.5 MB  conda-forge
#     fontconfig-2.14.2          |       h14ed4e7_0         266 KB  conda-forge
#     fonts-conda-ecosystem-1    |                0           4 KB  conda-forge
#     fonts-conda-forge-1        |                0           4 KB  conda-forge
#     freetype-2.12.1            |       h267a509_2         620 KB  conda-forge
#     giflib-5.2.2               |       hd590300_0          75 KB  conda-forge
#     graphite2-1.3.13           |    h59595ed_1003          95 KB  conda-forge
#     harfbuzz-8.5.0             |       hfac3d4d_0         1.5 MB  conda-forge
#     htslib-1.20                |       h5efdd21_2         2.9 MB  bioconda
#     lcms2-2.16                 |       hb7c19ff_0         239 KB  conda-forge
#     lerc-4.0.0                 |       h27087fc_0         275 KB  conda-forge
#     libcups-2.3.3              |       h4637d8d_4         4.3 MB  conda-forge
#     libcurl-8.8.0              |       hca28451_0         396 KB  conda-forge
#     libdeflate-1.20            |       hd590300_0          70 KB  conda-forge
#     libexpat-2.6.2             |       h59595ed_0          72 KB  conda-forge
#     libglib-2.80.2             |       hf974151_0         3.7 MB  conda-forge
#     libjpeg-turbo-3.0.0        |       hd590300_1         604 KB  conda-forge
#     libpng-1.6.43              |       h2797004_0         281 KB  conda-forge
#     libtiff-4.6.0              |       h1dd3fc0_3         276 KB  conda-forge
#     libwebp-base-1.4.0         |       hd590300_0         429 KB  conda-forge
#     libxcb-1.15                |       h0b41bf4_0         375 KB  conda-forge
#     ncurses-6.5                |       h59595ed_0         867 KB  conda-forge
#     nextflow-24.04.3           |       hdfd78af_0        30.7 MB  bioconda
#     openjdk-21.0.0             |       haa376d0_0       172.9 MB  conda-forge
#     openssl-3.3.1              |       h4bc722e_2         2.8 MB  conda-forge
#     pcre2-10.43                |       hcad00b1_0         929 KB  conda-forge
#     pixman-0.43.2              |       h59595ed_0         378 KB  conda-forge
#     pthread-stubs-0.4          |    h36c2ea0_1001           5 KB  conda-forge
#     samtools-1.20              |       h50ea8bc_1         470 KB  bioconda
#     xorg-fixesproto-5.0        |    h7f98852_1002           9 KB  conda-forge
#     xorg-inputproto-2.3.2      |    h7f98852_1002          19 KB  conda-forge
#     xorg-kbproto-1.0.7         |    h7f98852_1002          27 KB  conda-forge
#     xorg-libice-1.1.1          |       hd590300_0          57 KB  conda-forge
#     xorg-libsm-1.2.4           |       h7391055_0          27 KB  conda-forge
#     xorg-libx11-1.8.9          |       h8ee46fc_0         809 KB  conda-forge
#     xorg-libxau-1.0.11         |       hd590300_0          14 KB  conda-forge
#     xorg-libxdmcp-1.1.3        |       h7f98852_0          19 KB  conda-forge
#     xorg-libxext-1.3.4         |       h0b41bf4_2          49 KB  conda-forge
#     xorg-libxfixes-5.0.3       |    h7f98852_1004          18 KB  conda-forge
#     xorg-libxi-1.7.10          |       h7f98852_0          46 KB  conda-forge
#     xorg-libxrender-0.9.11     |       hd590300_0          37 KB  conda-forge
#     xorg-libxt-1.3.0           |       hd590300_1         370 KB  conda-forge
#     xorg-libxtst-1.2.4         |       h4bc722e_0          32 KB  conda-forge
#     xorg-recordproto-1.14.2    |    h7f98852_1002           8 KB  conda-forge
#     xorg-renderproto-0.11.1    |    h7f98852_1002           9 KB  conda-forge
#     xorg-xextproto-7.3.0       |    h0b41bf4_1003          30 KB  conda-forge
#     xorg-xproto-7.0.31         |    h7f98852_1007          73 KB  conda-forge
#     zlib-1.2.13                |       hd590300_5          91 KB  conda-forge
#     zstandard-0.23.0           |  py310h64cae3c_0         398 KB  conda-forge
#     zstd-1.5.6                 |       ha6fb4c9_0         542 KB  conda-forge
#     ------------------------------------------------------------
#                                            Total:       235.6 MB
#
# The following NEW packages will be INSTALLED:
#
#   alsa-lib           conda-forge/linux-64::alsa-lib-1.2.12-h4ab18f5_0
#   cairo              conda-forge/linux-64::cairo-1.18.0-h3faef2a_0
#   coreutils          conda-forge/linux-64::coreutils-9.5-hd590300_0
#   curl               conda-forge/linux-64::curl-8.8.0-he654da7_0
#   expat              conda-forge/linux-64::expat-2.6.2-h59595ed_0
#   font-ttf-dejavu-s~ conda-forge/noarch::font-ttf-dejavu-sans-mono-2.37-hab24e00_0
#   font-ttf-inconsol~ conda-forge/noarch::font-ttf-inconsolata-3.000-h77eed37_0
#   font-ttf-source-c~ conda-forge/noarch::font-ttf-source-code-pro-2.038-h77eed37_0
#   font-ttf-ubuntu    conda-forge/noarch::font-ttf-ubuntu-0.83-h77eed37_2
#   fontconfig         conda-forge/linux-64::fontconfig-2.14.2-h14ed4e7_0
#   fonts-conda-ecosy~ conda-forge/noarch::fonts-conda-ecosystem-1-0
#   fonts-conda-forge  conda-forge/noarch::fonts-conda-forge-1-0
#   freetype           conda-forge/linux-64::freetype-2.12.1-h267a509_2
#   giflib             conda-forge/linux-64::giflib-5.2.2-hd590300_0
#   graphite2          conda-forge/linux-64::graphite2-1.3.13-h59595ed_1003
#   harfbuzz           conda-forge/linux-64::harfbuzz-8.5.0-hfac3d4d_0
#   htslib             bioconda/linux-64::htslib-1.20-h5efdd21_2
#   lcms2              conda-forge/linux-64::lcms2-2.16-hb7c19ff_0
#   lerc               conda-forge/linux-64::lerc-4.0.0-h27087fc_0
#   libcups            conda-forge/linux-64::libcups-2.3.3-h4637d8d_4
#   libdeflate         conda-forge/linux-64::libdeflate-1.20-hd590300_0
#   libexpat           conda-forge/linux-64::libexpat-2.6.2-h59595ed_0
#   libglib            conda-forge/linux-64::libglib-2.80.2-hf974151_0
#   libjpeg-turbo      conda-forge/linux-64::libjpeg-turbo-3.0.0-hd590300_1
#   libpng             conda-forge/linux-64::libpng-1.6.43-h2797004_0
#   libtiff            conda-forge/linux-64::libtiff-4.6.0-h1dd3fc0_3
#   libwebp-base       conda-forge/linux-64::libwebp-base-1.4.0-hd590300_0
#   libxcb             conda-forge/linux-64::libxcb-1.15-h0b41bf4_0
#   nextflow           bioconda/noarch::nextflow-24.04.3-hdfd78af_0
#   openjdk            conda-forge/linux-64::openjdk-21.0.0-haa376d0_0
#   pcre2              conda-forge/linux-64::pcre2-10.43-hcad00b1_0
#   pixman             conda-forge/linux-64::pixman-0.43.2-h59595ed_0
#   pthread-stubs      conda-forge/linux-64::pthread-stubs-0.4-h36c2ea0_1001
#   samtools           bioconda/linux-64::samtools-1.20-h50ea8bc_1
#   xorg-fixesproto    conda-forge/linux-64::xorg-fixesproto-5.0-h7f98852_1002
#   xorg-inputproto    conda-forge/linux-64::xorg-inputproto-2.3.2-h7f98852_1002
#   xorg-kbproto       conda-forge/linux-64::xorg-kbproto-1.0.7-h7f98852_1002
#   xorg-libice        conda-forge/linux-64::xorg-libice-1.1.1-hd590300_0
#   xorg-libsm         conda-forge/linux-64::xorg-libsm-1.2.4-h7391055_0
#   xorg-libx11        conda-forge/linux-64::xorg-libx11-1.8.9-h8ee46fc_0
#   xorg-libxau        conda-forge/linux-64::xorg-libxau-1.0.11-hd590300_0
#   xorg-libxdmcp      conda-forge/linux-64::xorg-libxdmcp-1.1.3-h7f98852_0
#   xorg-libxext       conda-forge/linux-64::xorg-libxext-1.3.4-h0b41bf4_2
#   xorg-libxfixes     conda-forge/linux-64::xorg-libxfixes-5.0.3-h7f98852_1004
#   xorg-libxi         conda-forge/linux-64::xorg-libxi-1.7.10-h7f98852_0
#   xorg-libxrender    conda-forge/linux-64::xorg-libxrender-0.9.11-hd590300_0
#   xorg-libxt         conda-forge/linux-64::xorg-libxt-1.3.0-hd590300_1
#   xorg-libxtst       conda-forge/linux-64::xorg-libxtst-1.2.4-h4bc722e_0
#   xorg-recordproto   conda-forge/linux-64::xorg-recordproto-1.14.2-h7f98852_1002
#   xorg-renderproto   conda-forge/linux-64::xorg-renderproto-0.11.1-h7f98852_1002
#   xorg-xextproto     conda-forge/linux-64::xorg-xextproto-7.3.0-h0b41bf4_1003
#   xorg-xproto        conda-forge/linux-64::xorg-xproto-7.0.31-h7f98852_1007
#   zlib               conda-forge/linux-64::zlib-1.2.13-hd590300_5
#
# The following packages will be UPDATED:
#
#   ca-certificates                     2023.11.17-hbcca054_0 --> 2024.7.4-hbcca054_0
#   certifi                           2023.11.17-pyhd8ed1ab_0 --> 2024.7.4-pyhd8ed1ab_0
#   libcurl                                  8.5.0-hca28451_0 --> 8.8.0-hca28451_0
#   ncurses                                    6.4-h59595ed_2 --> 6.5-h59595ed_0
#   openssl                                  3.2.0-hd590300_1 --> 3.3.1-h4bc722e_2
#   zstandard                          0.22.0-py310h1275a96_0 --> 0.23.0-py310h64cae3c_0
#   zstd                                     1.5.5-hfc55251_0 --> 1.5.6-ha6fb4c9_0
#
#
#
# Downloading and Extracting Packages: ...working... done
# Preparing transaction: ...working... done
# Verifying transaction: ...working... done
# Executing transaction: ...working... done
# Warning: 'conda-forge' already in 'channels' list, moving to the top
#
#
# ==> WARNING: A newer version of conda exists. <==
#     current version: 23.11.0
#     latest version: 24.5.0
#
# Please update conda by running
#
#     $ conda update -n base -c conda-forge conda

# %%
# %%bash
# which nextflow
# Out:
# /usr/local/bin/nextflow

# %%
# !which samtools
# Out:
# /usr/local/bin/samtools

# %%
# !which nextflow
# Out:
# /usr/local/bin/nextflow

# %% [markdown]
# ### Find and download test data
# We will be using https://42basepairs.com/ browser to look for tumor/normal paired dataset in this exercise to do some variant calling.
#
# A good place to look for open bioinforamtics data and references on the cloud is [Open Data on AWS](https://registry.opendata.aws/tag/bioinformatics/)

# %% [markdown]
# Let's download 2 pairs of tumor/normal pairs from [TCGA DREAM challenge](https://42basepairs.com/browse/gs/broad-public-datasets/TCGA_DREAM). Because we have limited space on the colab runtime, we will subset the BAMs to the TP53 gene regions (chr17:7,571,739-7,590,808, GRCh37) only on the fly and download that region only.

# %%
# !gsutil ls gs://broad-public-datasets/TCGA_DREAM/
# Out:
# gs://broad-public-datasets/TCGA_DREAM/README.txt
# gs://broad-public-datasets/TCGA_DREAM/synthetic.challenge.set1.normal.bai
# gs://broad-public-datasets/TCGA_DREAM/synthetic.challenge.set1.normal.bam
# gs://broad-public-datasets/TCGA_DREAM/synthetic.challenge.set1.tumor.bai
# gs://broad-public-datasets/TCGA_DREAM/synthetic.challenge.set1.tumor.bam
# gs://broad-public-datasets/TCGA_DREAM/synthetic.challenge.set2.normal.bai
# gs://broad-public-datasets/TCGA_DREAM/synthetic.challenge.set2.normal.bam
# gs://broad-public-datasets/TCGA_DREAM/synthetic.challenge.set2.tumor.bai
# gs://broad-public-datasets/TCGA_DREAM/synthetic.challenge.set2.tumor.bam
# gs://broad-public-datasets/TCGA_DREAM/synthetic.challenge.set3.normal.bai
# gs://broad-public-datasets/TCGA_DREAM/synthetic.challenge.set3.normal.bam
# gs://broad-public-datasets/TCGA_DREAM/synthetic.challenge.set3.tumor.bai
# gs://broad-public-datasets/TCGA_DREAM/synthetic.challenge.set3.tumor.bam
# gs://broad-public-datasets/TCGA_DREAM/synthetic.challenge.set4.normal.bai
# gs://broad-public-datasets/TCGA_DREAM/synthetic.challenge.set4.normal.bam
# gs://broad-public-datasets/TCGA_DREAM/synthetic.challenge.set4.tumor.bai
# gs://broad-public-datasets/TCGA_DREAM/synthetic.challenge.set4.tumor.bam

# %%
# %%bash
# tp53_grch37_region="17:7571739-7590808"
# samtools view -b gs://broad-public-datasets/TCGA_DREAM/synthetic.challenge.set1.tumor.bam ${tp53_grch37_region} >set1.tumor.tp53.bam
# samtools view -b gs://broad-public-datasets/TCGA_DREAM/synthetic.challenge.set1.normal.bam ${tp53_grch37_region} >set1.normal.tp53.bam
# samtools view -b gs://broad-public-datasets/TCGA_DREAM/synthetic.challenge.set2.tumor.bam ${tp53_grch37_region} >set2.tumor.tp53.bam
# samtools view -b gs://broad-public-datasets/TCGA_DREAM/synthetic.challenge.set2.normal.bam ${tp53_grch37_region} >set2.normal.tp53.bam
#
# samtools index set1.tumor.tp53.bam
# samtools index set1.normal.tp53.bam
# samtools index set2.tumor.tp53.bam
# samtools index set2.normal.tp53.bam

# %%
# %%bash
# echo -e "17\t7571739\t7590808" >tp53.bed

# %%
# %%bash
# echo -e "patient,status,sample,bam,bai
# sample1,1,tumor_sample1,set1.tumor.tp53.bam,set1.tumor.tp53.bam.bai
# sample1,0,normal_sample1,set1.normal.tp53.bam,set1.normal.tp53.bam.bai
# sample2,1,tumor_sample2,set2.tumor.tp53.bam,set2.tumor.tp53.bam.bai
# sample2,0,normal_sample2,set2.normal.tp53.bam,set2.normal.tp53.bam.bai" > samplesheet.csv

# %% [markdown]
# ### Run the sarek workflow with nextflow
# [Sarek](https://nf-co.re/sarek/3.4.2/) is a comprehensive and modular Nextflow workflow designed for the analysis of germline and somatic variations in whole genome and exome sequencing data.

# %%
# %%bash
# wget --no-verbose https://data.broadinstitute.org/snowman/hg19/Homo_sapiens_assembly19.fasta
# wget --no-verbose https://data.broadinstitute.org/snowman/hg19/Homo_sapiens_assembly19.fasta.fai
# wget --no-verbose https://data.broadinstitute.org/snowman/hg19/Homo_sapiens_assembly19.dict
# Out:
# 2024-07-25 17:14:00 URL:https://data.broadinstitute.org/snowman/hg19/Homo_sapiens_assembly19.fasta [3140756381/3140756381] -> "Homo_sapiens_assembly19.fasta" [1]
# 2024-07-25 17:14:00 URL:https://data.broadinstitute.org/snowman/hg19/Homo_sapiens_assembly19.fasta.fai [2780/2780] -> "Homo_sapiens_assembly19.fasta.fai" [1]
# 2024-07-25 17:14:00 URL:https://data.broadinstitute.org/snowman/hg19/Homo_sapiens_assembly19.dict [14811/14811] -> "Homo_sapiens_assembly19.dict" [1]

# %%
# %%bash
# nextflow run nf-core/sarek -r 3.4.2 -profile conda --max_cpus 2 --max_memory 8GB \
#  --input ./samplesheet.csv --outdir ./results --fasta ./Homo_sapiens_assembly19.fasta --fasta_fai ./Homo_sapiens_assembly19.fasta.fai \
#  --genome null --igenomes_ignore --step variant_calling \
#  --wes --intervals tp53.bed \
#  --tools strelka --only_paired_variant_calling
# Out:
#  N E X T F L O W   ~  version 24.04.3
#
# Pulling nf-core/sarek ...
#  downloaded from https://github.com/nf-core/sarek.git
# Launching `https://github.com/nf-core/sarek` [furious_miescher] DSL2 - revision: b5b766d3b4 [3.4.2]
#
# Downloading plugin nf-validation@1.1.3
# Downloading plugin nf-prov@1.2.2
# WARN: ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#   There is a problem with your Conda configuration!
#
#   You will need to set-up the conda-forge and bioconda channels correctly.
#   Please refer to https://bioconda.github.io/
#   The observed channel order is
#   [conda-forge, bioconda]
#   but the following channel order is required:
#   [conda-forge, bioconda, defaults]
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# WARN: Access to undefined parameter `monochromeLogs` -- Initialise it to a default value eg. `params.monochromeLogs = some_value`
#
#
# ------------------------------------------------------
#                                         ,--./,-.
#         ___     __   __   __   ___     /,-._.--~'
#   |\ | |__  __ /  ` /  \ |__) |__         }  {
#   | \| |       \__, \__/ |  \ |___     \`-._,-`-,
#                                         `._,._,'
#       ____
#     .´ _  `.
#    /  |\`-_ \      __        __   ___
#   |   | \  `-|    |__`  /\  |__) |__  |__/
#    \ |   \  /     .__| /¯¯\ |  \ |___ |  \
#     `|____\´
#
#   nf-core/sarek v3.4.2-gb5b766d
# ------------------------------------------------------
# Core Nextflow options
#   revision                   : 3.4.2
#   runName                    : furious_miescher
#   launchDir                  : /content
#   workDir                    : /content/work
#   projectDir                 : /root/.nextflow/assets/nf-core/sarek
#   userName                   : root
#   profile                    : conda
#   configFiles                :
#
# Input/output options
#   input                      : ./samplesheet.csv
#   step                       : variant_calling
#   outdir                     : ./results
#
# Main options
#   wes                        : true
#   intervals                  : tp53.bed
#   tools                      : strelka
#
# Variant Calling
#   only_paired_variant_calling: true
#
# Reference genome options
#   genome                     : null
#   fasta                      : ./Homo_sapiens_assembly19.fasta
#   fasta_fai                  : ./Homo_sapiens_assembly19.fasta.fai
#   igenomes_ignore            : true
#
# Max job request options
#   max_cpus                   : 2
#   max_memory                 : 8GB
#
# Generic options
#   validationLenientMode      : true
#
# !! Only displaying parameters that differ from the pipeline defaults !!
# ------------------------------------------------------
# If you use nf-core/sarek for your analysis please cite:
#
# * The pipeline
#   https://doi.org/10.12688/f1000research.16665.2
#   https://doi.org/10.1093/nargab/lqae031
#   https://doi.org/10.5281/zenodo.3476425
#
# * The nf-core framework
#   https://doi.org/10.1038/s41587-020-0439-x
#
# * Software dependencies
#   https://github.com/nf-core/sarek/blob/master/CITATIONS.md
# ------------------------------------------------------
# [-        ] NFC…EPARE_GENOME:BWAMEM1_INDEX -
#
# [-        ] NFC…EPARE_GENOME:BWAMEM1_INDEX -
# [-        ] NFC…EPARE_GENOME:BWAMEM2_INDEX -
# [-        ] NFC…E_GENOME:DRAGMAP_HASHTABLE -
# [-        ] NFC…4_CREATESEQUENCEDICTIONARY -
#
# [-        ] NFC…EPARE_GENOME:BWAMEM1_INDEX -
# [-        ] NFC…EPARE_GENOME:BWAMEM2_INDEX -
# [-        ] NFC…E_GENOME:DRAGMAP_HASHTABLE -
# [-        ] NFC…4_CREATESEQUENCEDICTIONARY -
# [-        ] NFC…E_GENOME:MSISENSORPRO_SCAN -
# [-        ] NFC…PARE_GENOME:SAMTOOLS_FAIDX -
#
# [-        ] NFC…EPARE_GENOME:BWAMEM1_INDEX -
# [-        ] NFC…EPARE_GENOME:BWAMEM2_INDEX -
# [-        ] NFC…E_GENOME:DRAGMAP_HASHTABLE -
# [-        ] NFC…4_CREATESEQUENCEDICTIONARY -
# [-        ] NFC…E_GENOME:MSISENSORPRO_SCAN -
# [-        ] NFC…PARE_GENOME:SAMTOOLS_FAIDX -
# [-        ] NFC…TABIX_BCFTOOLS_ANNOTATIONS -
#
# [-        ] NFC…EPARE_GENOME:BWAMEM1_INDEX -
# [-        ] NFC…EPARE_GENOME:BWAMEM2_INDEX -
# [-        ] NFC…E_GENOME:DRAGMAP_HASHTABLE -
# [-        ] NFC…4_CREATESEQUENCEDICTIONARY -
# [-        ] NFC…E_GENOME:MSISENSORPRO_SCAN -
# [-        ] NFC…PARE_GENOME:SAMTOOLS_FAIDX -
# [-        ] NFC…TABIX_BCFTOOLS_ANNOTATIONS -
# [-        ] NFC…PREPARE_GENOME:TABIX_DBSNP -
# [-        ] NFC…ME:TABIX_GERMLINE_RESOURCE -
#
# [-        ] NFC…EPARE_GENOME:BWAMEM1_INDEX -
# [-        ] NFC…EPARE_GENOME:BWAMEM2_INDEX -
# [-        ] NFC…E_GENOME:DRAGMAP_HASHTABLE -
# [-        ] NFC…4_CREATESEQUENCEDICTIONARY -
# [-        ] NFC…E_GENOME:MSISENSORPRO_SCAN -
# [-        ] NFC…PARE_GENOME:SAMTOOLS_FAIDX -
# [-        ] NFC…TABIX_BCFTOOLS_ANNOTATIONS -
# [-        ] NFC…PREPARE_GENOME:TABIX_DBSNP -
# [-        ] NFC…ME:TABIX_GERMLINE_RESOURCE -
# [-        ] NFC…RE_GENOME:TABIX_KNOWN_SNPS -
# [-        ] NFC…_GENOME:TABIX_KNOWN_INDELS -
#
# [-        ] NFC…EPARE_GENOME:BWAMEM1_INDEX -
# [-        ] NFC…EPARE_GENOME:BWAMEM2_INDEX -
# [-        ] NFC…E_GENOME:DRAGMAP_HASHTABLE -
# [-        ] NFC…4_CREATESEQUENCEDICTIONARY -
# [-        ] NFC…E_GENOME:MSISENSORPRO_SCAN -
# [-        ] NFC…PARE_GENOME:SAMTOOLS_FAIDX -
# [-        ] NFC…TABIX_BCFTOOLS_ANNOTATIONS -
# [-        ] NFC…PREPARE_GENOME:TABIX_DBSNP -
# [-        ] NFC…ME:TABIX_GERMLINE_RESOURCE -
# [-        ] NFC…RE_GENOME:TABIX_KNOWN_SNPS -
# [-        ] NFC…_GENOME:TABIX_KNOWN_INDELS -
# [-        ] NFC…K:PREPARE_GENOME:TABIX_PON -
#
# [-        ] NFC…EPARE_GENOME:BWAMEM1_INDEX -
# [-        ] NFC…EPARE_GENOME:BWAMEM2_INDEX -
# [-        ] NFC…E_GENOME:DRAGMAP_HASHTABLE -
# [-        ] NFC…4_CREATESEQUENCEDICTIONARY -
# [-        ] NFC…E_GENOME:MSISENSORPRO_SCAN -
# [-        ] NFC…PARE_GENOME:SAMTOOLS_FAIDX -
# [-        ] NFC…TABIX_BCFTOOLS_ANNOTATIONS -
# [-        ] NFC…PREPARE_GENOME:TABIX_DBSNP -
# [-        ] NFC…ME:TABIX_GERMLINE_RESOURCE -
# [-        ] NFC…RE_GENOME:TABIX_KNOWN_SNPS -
# [-        ] NFC…_GENOME:TABIX_KNOWN_INDELS -
# [-        ] NFC…K:PREPARE_GENOME:TABIX_PON -
# [-        ] NFC…RVALS:CREATE_INTERVALS_BED -
#
# [-        ] NFC…EPARE_GENOME:BWAMEM1_INDEX -
# [-        ] NFC…EPARE_GENOME:BWAMEM2_INDEX -
# [-        ] NFC…E_GENOME:DRAGMAP_HASHTABLE -
# [-        ] NFC…4_CREATESEQUENCEDICTIONARY -
# [-        ] NFC…E_GENOME:MSISENSORPRO_SCAN -
# [-        ] NFC…PARE_GENOME:SAMTOOLS_FAIDX -
# [-        ] NFC…TABIX_BCFTOOLS_ANNOTATIONS -
# [-        ] NFC…PREPARE_GENOME:TABIX_DBSNP -
# [-        ] NFC…ME:TABIX_GERMLINE_RESOURCE -
# [-        ] NFC…RE_GENOME:TABIX_KNOWN_SNPS -
# [-        ] NFC…_GENOME:TABIX_KNOWN_INDELS -
# [-        ] NFC…K:PREPARE_GENOME:TABIX_PON -
# [-        ] NFC…RVALS:CREATE_INTERVALS_BED -
# [-        ] NFC…_BGZIPTABIX_INTERVAL_SPLIT -
#
# [-        ] NFC…EPARE_GENOME:BWAMEM1_INDEX -
# [-        ] NFC…EPARE_GENOME:BWAMEM2_INDEX -
# [-        ] NFC…E_GENOME:DRAGMAP_HASHTABLE -
# [-        ] NFC…4_CREATESEQUENCEDICTIONARY -
# [-        ] NFC…E_GENOME:MSISENSORPRO_SCAN -
# [-        ] NFC…PARE_GENOME:SAMTOOLS_FAIDX -
# [-        ] NFC…TABIX_BCFTOOLS_ANNOTATIONS -
# [-        ] NFC…PREPARE_GENOME:TABIX_DBSNP -
# [-        ] NFC…ME:TABIX_GERMLINE_RESOURCE -
# [-        ] NFC…RE_GENOME:TABIX_KNOWN_SNPS -
# [-        ] NFC…_GENOME:TABIX_KNOWN_INDELS -
# [-        ] NFC…K:PREPARE_GENOME:TABIX_PON -
# [-        ] NFC…RVALS:CREATE_INTERVALS_BED -
# [-        ] NFC…_BGZIPTABIX_INTERVAL_SPLIT -
# [-        ] NFC…ZIPTABIX_INTERVAL_COMBINED -
#
# [-        ] NFC…EPARE_GENOME:BWAMEM1_INDEX -
# [-        ] NFC…EPARE_GENOME:BWAMEM2_INDEX -
# [-        ] NFC…E_GENOME:DRAGMAP_HASHTABLE -
# [-        ] NFC…4_CREATESEQUENCEDICTIONARY -
# [-        ] NFC…E_GENOME:MSISENSORPRO_SCAN -
# [-        ] NFC…PARE_GENOME:SAMTOOLS_FAIDX -
# [-        ] NFC…TABIX_BCFTOOLS_ANNOTATIONS -
# [-        ] NFC…PREPARE_GENOME:TABIX_DBSNP -
# [-        ] NFC…ME:TABIX_GERMLINE_RESOURCE -
# [-        ] NFC…RE_GENOME:TABIX_KNOWN_SNPS -
# [-        ] NFC…_GENOME:TABIX_KNOWN_INDELS -
# [-        ] NFC…K:PREPARE_GENOME:TABIX_PON -
# [-        ] NFC…RVALS:CREATE_INTERVALS_BED -
# [-        ] NFC…_BGZIPTABIX_INTERVAL_SPLIT -
# [-        ] NFC…ZIPTABIX_INTERVAL_COMBINED -
# [-        ] NFCORE_SAREK:SAREK:BAM_TO_CRAM -
#
# [-        ] NFC…EPARE_GENOME:BWAMEM1_INDEX -
# [-        ] NFC…EPARE_GENOME:BWAMEM2_INDEX -
# [-        ] NFC…E_GENOME:DRAGMAP_HASHTABLE -
# [-        ] NFC…4_CREATESEQUENCEDICTIONARY -
# [-        ] NFC…E_GENOME:MSISENSORPRO_SCAN -
# [-        ] NFC…PARE_GENOME:SAMTOOLS_FAIDX -
# [-        ] NFC…TABIX_BCFTOOLS_ANNOTATIONS -
# [-        ] NFC…PREPARE_GENOME:TABIX_DBSNP -
# [-        ] NFC…ME:TABIX_GERMLINE_RESOURCE -
# [-        ] NFC…RE_GENOME:TABIX_KNOWN_SNPS -
# [-        ] NFC…_GENOME:TABIX_KNOWN_INDELS -
# [-        ] NFC…K:PREPARE_GENOME:TABIX_PON -
# [-        ] NFC…RVALS:CREATE_INTERVALS_BED -
# [-        ] NFC…_BGZIPTABIX_INTERVAL_SPLIT -
# [-        ] NFC…ZIPTABIX_INTERVAL_COMBINED -
# [-        ] NFCORE_SAREK:SAREK:BAM_TO_CRAM -
# [-        ] NFC…AM_QC_RECAL:SAMTOOLS_STATS -
#
# [-        ] NFC…EPARE_GENOME:BWAMEM1_INDEX -
# [-        ] NFC…EPARE_GENOME:BWAMEM2_INDEX -
# [-        ] NFC…E_GENOME:DRAGMAP_HASHTABLE -
# [-        ] NFC…4_CREATESEQUENCEDICTIONARY -
# [-        ] NFC…E_GENOME:MSISENSORPRO_SCAN -
# [-        ] NFC…PARE_GENOME:SAMTOOLS_FAIDX -
# [-        ] NFC…TABIX_BCFTOOLS_ANNOTATIONS -
# [-        ] NFC…PREPARE_GENOME:TABIX_DBSNP -
# [-        ] NFC…ME:TABIX_GERMLINE_RESOURCE -
# [-        ] NFC…RE_GENOME:TABIX_KNOWN_SNPS -
# [-        ] NFC…_GENOME:TABIX_KNOWN_INDELS -
# [-        ] NFC…K:PREPARE_GENOME:TABIX_PON -
# [-        ] NFC…RVALS:CREATE_INTERVALS_BED -
# [-        ] NFC…_BGZIPTABIX_INTERVAL_SPLIT -
# [-        ] NFC…ZIPTABIX_INTERVAL_COMBINED -
# [-        ] NFCORE_SAREK:SAREK:BAM_TO_CRAM -
# [-        ] NFC…AM_QC_RECAL:SAMTOOLS_STATS -
# [-        ] NFC…EQC:CRAM_QC_RECAL:MOSDEPTH -
#
# [-        ] NFC…EPARE_GENOME:BWAMEM1_INDEX -
# [-        ] NFC…EPARE_GENOME:BWAMEM2_INDEX -
# [-        ] NFC…E_GENOME:DRAGMAP_HASHTABLE -
# [-        ] NFC…4_CREATESEQUENCEDICTIONARY -
# [-        ] NFC…E_GENOME:MSISENSORPRO_SCAN -
# [-        ] NFC…PARE_GENOME:SAMTOOLS_FAIDX -
# [-        ] NFC…TABIX_BCFTOOLS_ANNOTATIONS -
# [-        ] NFC…PREPARE_GENOME:TABIX_DBSNP -
# [-        ] NFC…ME:TABIX_GERMLINE_RESOURCE -
# [-        ] NFC…RE_GENOME:TABIX_KNOWN_SNPS -
# [-        ] NFC…_GENOME:TABIX_KNOWN_INDELS -
# [-        ] NFC…K:PREPARE_GENOME:TABIX_PON -
# [-        ] NFC…RVALS:CREATE_INTERVALS_BED -
# [-        ] NFC…_BGZIPTABIX_INTERVAL_SPLIT -
# [-        ] NFC…ZIPTABIX_INTERVAL_COMBINED -
# [-        ] NFCORE_SAREK:SAREK:BAM_TO_CRAM -
# [-        ] NFC…AM_QC_RECAL:SAMTOOLS_STATS -
# [-        ] NFC…EQC:CRAM_QC_RECAL:MOSDEPTH -
# [-        ] NFC…CHECKMATE:BCFTOOLS_MPILEUP -
#
# [-        ] NFC…EPARE_GENOME:BWAMEM1_INDEX -
# [-        ] NFC…EPARE_GENOME:BWAMEM2_INDEX -
# [-        ] NFC…E_GENOME:DRAGMAP_HASHTABLE -
# [-        ] NFC…4_CREATESEQUENCEDICTIONARY -
# [-        ] NFC…E_GENOME:MSISENSORPRO_SCAN -
# [-        ] NFC…PARE_GENOME:SAMTOOLS_FAIDX -
# [-        ] NFC…TABIX_BCFTOOLS_ANNOTATIONS -
# [-        ] NFC…PREPARE_GENOME:TABIX_DBSNP -
# [-        ] NFC…ME:TABIX_GERMLINE_RESOURCE -
# [-        ] NFC…RE_GENOME:TABIX_KNOWN_SNPS -
# [-        ] NFC…_GENOME:TABIX_KNOWN_INDELS -
# [-        ] NFC…K:PREPARE_GENOME:TABIX_PON -
# [-        ] NFC…RVALS:CREATE_INTERVALS_BED -
# [-        ] NFC…_BGZIPTABIX_INTERVAL_SPLIT -
# [-        ] NFC…ZIPTABIX_INTERVAL_COMBINED -
# [-        ] NFCORE_SAREK:SAREK:BAM_TO_CRAM -
# [-        ] NFC…AM_QC_RECAL:SAMTOOLS_STATS -
# [-        ] NFC…EQC:CRAM_QC_RECAL:MOSDEPTH -
# [-        ] NFC…CHECKMATE:BCFTOOLS_MPILEUP -
# [-        ] NFC…CHECKMATE:NGSCHECKMATE_NCM -
#
# [-        ] NFC…EPARE_GENOME:BWAMEM1_INDEX -
# [-        ] NFC…EPARE_GENOME:BWAMEM2_INDEX -
# [-        ] NFC…E_GENOME:DRAGMAP_HASHTABLE -
# [-        ] NFC…4_CREATESEQUENCEDICTIONARY -
# [-        ] NFC…E_GENOME:MSISENSORPRO_SCAN -
# [-        ] NFC…PARE_GENOME:SAMTOOLS_FAIDX -
# [-        ] NFC…TABIX_BCFTOOLS_ANNOTATIONS -
# [-        ] NFC…PREPARE_GENOME:TABIX_DBSNP -
# [-        ] NFC…ME:TABIX_GERMLINE_RESOURCE -
# [-        ] NFC…RE_GENOME:TABIX_KNOWN_SNPS -
# [-        ] NFC…_GENOME:TABIX_KNOWN_INDELS -
# [-        ] NFC…K:PREPARE_GENOME:TABIX_PON -
# [-        ] NFC…RVALS:CREATE_INTERVALS_BED -
# [-        ] NFC…_BGZIPTABIX_INTERVAL_SPLIT -
# [-        ] NFC…ZIPTABIX_INTERVAL_COMBINED -
# [-        ] NFCORE_SAREK:SAREK:BAM_TO_CRAM -
# [-        ] NFC…AM_QC_RECAL:SAMTOOLS_STATS -
# [-        ] NFC…EQC:CRAM_QC_RECAL:MOSDEPTH -
# [-        ] NFC…CHECKMATE:BCFTOOLS_MPILEUP -
# [-        ] NFC…CHECKMATE:NGSCHECKMATE_NCM -
# Plus 1 more processes waiting for tasks…
#
# [-        ] NFC…EPARE_GENOME:BWAMEM1_INDEX -
# [-        ] NFC…EPARE_GENOME:BWAMEM2_INDEX -
# [-        ] NFC…E_GENOME:DRAGMAP_HASHTABLE -
# [-        ] NFC…4_CREATESEQUENCEDICTIONARY -
# [-        ] NFC…E_GENOME:MSISENSORPRO_SCAN -
# [-        ] NFC…PARE_GENOME:SAMTOOLS_FAIDX -
# [-        ] NFC…TABIX_BCFTOOLS_ANNOTATIONS -
# [-        ] NFC…PREPARE_GENOME:TABIX_DBSNP -
# [-        ] NFC…ME:TABIX_GERMLINE_RESOURCE -
# [-        ] NFC…RE_GENOME:TABIX_KNOWN_SNPS -
# [-        ] NFC…_GENOME:TABIX_KNOWN_INDELS -
# [-        ] NFC…K:PREPARE_GENOME:TABIX_PON -
# [-        ] NFC…RVALS:CREATE_INTERVALS_BED -
# [-        ] NFC…_BGZIPTABIX_INTERVAL_SPLIT -
# [-        ] NFC…ZIPTABIX_INTERVAL_COMBINED -
# [-        ] NFCORE_SAREK:SAREK:BAM_TO_CRAM -
# [-        ] NFC…AM_QC_RECAL:SAMTOOLS_STATS -
# [-        ] NFC…EQC:CRAM_QC_RECAL:MOSDEPTH -
# [-        ] NFC…CHECKMATE:BCFTOOLS_MPILEUP -
# [-        ] NFC…CHECKMATE:NGSCHECKMATE_NCM -
# Plus 3 more processes waiting for tasks…
#
# [-        ] NFC…EPARE_GENOME:BWAMEM1_INDEX -
# [-        ] NFC…EPARE_GENOME:BWAMEM2_INDEX -
# [-        ] NFC…E_GENOME:DRAGMAP_HASHTABLE -
# [-        ] NFC…4_CREATESEQUENCEDICTIONARY -
# [-        ] NFC…E_GENOME:MSISENSORPRO_SCAN -
# [-        ] NFC…PARE_GENOME:SAMTOOLS_FAIDX -
# [-        ] NFC…TABIX_BCFTOOLS_ANNOTATIONS -
# [-        ] NFC…PREPARE_GENOME:TABIX_DBSNP -
# [-        ] NFC…ME:TABIX_GERMLINE_RESOURCE -
# [-        ] NFC…RE_GENOME:TABIX_KNOWN_SNPS -
# [-        ] NFC…_GENOME:TABIX_KNOWN_INDELS -
# [-        ] NFC…K:PREPARE_GENOME:TABIX_PON -
# [-        ] NFC…RVALS:CREATE_INTERVALS_BED -
# [-        ] NFC…_BGZIPTABIX_INTERVAL_SPLIT -
# [-        ] NFC…ZIPTABIX_INTERVAL_COMBINED -
# [-        ] NFCORE_SAREK:SAREK:BAM_TO_CRAM -
# [-        ] NFC…AM_QC_RECAL:SAMTOOLS_STATS -
# [-        ] NFC…EQC:CRAM_QC_RECAL:MOSDEPTH -
# [-        ] NFC…CHECKMATE:BCFTOOLS_MPILEUP -
# [-        ] NFC…CHECKMATE:NGSCHECKMATE_NCM -
# Plus 6 more processes waiting for tasks…
#
# [-        ] NFC…EPARE_GENOME:BWAMEM1_INDEX -
# [-        ] NFC…EPARE_GENOME:BWAMEM2_INDEX -
# [-        ] NFC…E_GENOME:DRAGMAP_HASHTABLE -
# [-        ] NFC…4_CREATESEQUENCEDICTIONARY -
# [-        ] NFC…E_GENOME:MSISENSORPRO_SCAN -
# [-        ] NFC…PARE_GENOME:SAMTOOLS_FAIDX -
# [-        ] NFC…TABIX_BCFTOOLS_ANNOTATIONS -
# [-        ] NFC…PREPARE_GENOME:TABIX_DBSNP -
# [-        ] NFC…ME:TABIX_GERMLINE_RESOURCE -
# [-        ] NFC…RE_GENOME:TABIX_KNOWN_SNPS -
# [-        ] NFC…_GENOME:TABIX_KNOWN_INDELS -
# [-        ] NFC…K:PREPARE_GENOME:TABIX_PON -
# [-        ] NFC…RVALS:CREATE_INTERVALS_BED -
# [-        ] NFC…_BGZIPTABIX_INTERVAL_SPLIT -
# [-        ] NFC…ZIPTABIX_INTERVAL_COMBINED -
# [-        ] NFCORE_SAREK:SAREK:BAM_TO_CRAM -
# [-        ] NFC…AM_QC_RECAL:SAMTOOLS_STATS -
# [-        ] NFC…EQC:CRAM_QC_RECAL:MOSDEPTH -
# [-        ] NFC…CHECKMATE:BCFTOOLS_MPILEUP -
# [-        ] NFC…CHECKMATE:NGSCHECKMATE_NCM -
# Plus 7 more processes waiting for tasks…
#
# [-        ] NFC…EPARE_GENOME:BWAMEM1_INDEX -
# [-        ] NFC…EPARE_GENOME:BWAMEM2_INDEX -
# [-        ] NFC…E_GENOME:DRAGMAP_HASHTABLE -
# [-        ] NFC…4_CREATESEQUENCEDICTIONARY -
# [-        ] NFC…E_GENOME:MSISENSORPRO_SCAN -
# [-        ] NFC…PARE_GENOME:SAMTOOLS_FAIDX -
# [-        ] NFC…TABIX_BCFTOOLS_ANNOTATIONS -
# [-        ] NFC…PREPARE_GENOME:TABIX_DBSNP -
# [-        ] NFC…ME:TABIX_GERMLINE_RESOURCE -
# [-        ] NFC…RE_GENOME:TABIX_KNOWN_SNPS -
# [-        ] NFC…_GENOME:TABIX_KNOWN_INDELS -
# [-        ] NFC…K:PREPARE_GENOME:TABIX_PON -
# [-        ] NFC…RVALS:CREATE_INTERVALS_BED -
# [-        ] NFC…_BGZIPTABIX_INTERVAL_SPLIT -
# [-        ] NFC…ZIPTABIX_INTERVAL_COMBINED -
# [-        ] NFCORE_SAREK:SAREK:BAM_TO_CRAM -
# [-        ] NFC…AM_QC_RECAL:SAMTOOLS_STATS -
# [-        ] NFC…EQC:CRAM_QC_RECAL:MOSDEPTH -
# [-        ] NFC…CHECKMATE:BCFTOOLS_MPILEUP -
# [-        ] NFC…CHECKMATE:NGSCHECKMATE_NCM -
# Plus 9 more processes waiting for tasks…
#
# [-        ] NFC…EPARE_GENOME:BWAMEM1_INDEX -
# [-        ] NFC…EPARE_GENOME:BWAMEM2_INDEX -
# [-        ] NFC…E_GENOME:DRAGMAP_HASHTABLE -
# [-        ] NFC…4_CREATESEQUENCEDICTIONARY -
# [-        ] NFC…E_GENOME:MSISENSORPRO_SCAN -
# [-        ] NFC…PARE_GENOME:SAMTOOLS_FAIDX -
# [-        ] NFC…TABIX_BCFTOOLS_ANNOTATIONS -
# [-        ] NFC…PREPARE_GENOME:TABIX_DBSNP -
# [-        ] NFC…ME:TABIX_GERMLINE_RESOURCE -
# [-        ] NFC…RE_GENOME:TABIX_KNOWN_SNPS -
# [-        ] NFC…_GENOME:TABIX_KNOWN_INDELS -
# [-        ] NFC…K:PREPARE_GENOME:TABIX_PON -
# [-        ] NFC…RVALS:CREATE_INTERVALS_BED -
# [-        ] NFC…_BGZIPTABIX_INTERVAL_SPLIT -
# [-        ] NFC…ZIPTABIX_INTERVAL_COMBINED -
# [-        ] NFCORE_SAREK:SAREK:BAM_TO_CRAM -
# [-        ] NFC…AM_QC_RECAL:SAMTOOLS_STATS -
# [-        ] NFC…EQC:CRAM_QC_RECAL:MOSDEPTH -
# [-        ] NFC…CHECKMATE:BCFTOOLS_MPILEUP -
# [-        ] NFC…CHECKMATE:NGSCHECKMATE_NCM -
# Plus 10 more processes waiting for tasks…
#
# [-        ] NFC…EPARE_GENOME:BWAMEM1_INDEX -
# [-        ] NFC…EPARE_GENOME:BWAMEM2_INDEX -
# [-        ] NFC…E_GENOME:DRAGMAP_HASHTABLE -
# [-        ] NFC…4_CREATESEQUENCEDICTIONARY -
# [-        ] NFC…E_GENOME:MSISENSORPRO_SCAN -
# [-        ] NFC…PARE_GENOME:SAMTOOLS_FAIDX -
# [-        ] NFC…TABIX_BCFTOOLS_ANNOTATIONS -
# [-        ] NFC…PREPARE_GENOME:TABIX_DBSNP -
# [-        ] NFC…ME:TABIX_GERMLINE_RESOURCE -
# [-        ] NFC…RE_GENOME:TABIX_KNOWN_SNPS -
# [-        ] NFC…_GENOME:TABIX_KNOWN_INDELS -
# [-        ] NFC…K:PREPARE_GENOME:TABIX_PON -
# [-        ] NFC…RVALS:CREATE_INTERVALS_BED -
# [-        ] NFC…_BGZIPTABIX_INTERVAL_SPLIT -
# [-        ] NFC…ZIPTABIX_INTERVAL_COMBINED -
# [-        ] NFCORE_SAREK:SAREK:BAM_TO_CRAM -
# [-        ] NFC…AM_QC_RECAL:SAMTOOLS_STATS -
# [-        ] NFC…EQC:CRAM_QC_RECAL:MOSDEPTH -
# [-        ] NFC…CHECKMATE:BCFTOOLS_MPILEUP -
# [-        ] NFC…CHECKMATE:NGSCHECKMATE_NCM -
# Plus 11 more processes waiting for tasks…
#
# [-        ] NFC…EPARE_GENOME:BWAMEM1_INDEX -
# [-        ] NFC…EPARE_GENOME:BWAMEM2_INDEX -
# [-        ] NFC…E_GENOME:DRAGMAP_HASHTABLE -
# [-        ] NFC…4_CREATESEQUENCEDICTIONARY -
# [-        ] NFC…E_GENOME:MSISENSORPRO_SCAN -
# [-        ] NFC…PARE_GENOME:SAMTOOLS_FAIDX -
# [-        ] NFC…TABIX_BCFTOOLS_ANNOTATIONS -
# [-        ] NFC…PREPARE_GENOME:TABIX_DBSNP -
# [-        ] NFC…ME:TABIX_GERMLINE_RESOURCE -
# [-        ] NFC…RE_GENOME:TABIX_KNOWN_SNPS -
# [-        ] NFC…_GENOME:TABIX_KNOWN_INDELS -
# [-        ] NFC…K:PREPARE_GENOME:TABIX_PON -
# [-        ] NFC…RVALS:CREATE_INTERVALS_BED -
# [-        ] NFC…_BGZIPTABIX_INTERVAL_SPLIT -
# [-        ] NFC…ZIPTABIX_INTERVAL_COMBINED -
# [-        ] NFCORE_SAREK:SAREK:BAM_TO_CRAM -
# [-        ] NFC…AM_QC_RECAL:SAMTOOLS_STATS -
# [-        ] NFC…EQC:CRAM_QC_RECAL:MOSDEPTH -
# [-        ] NFC…CHECKMATE:BCFTOOLS_MPILEUP -
# [-        ] NFC…CHECKMATE:NGSCHECKMATE_NCM -
# Plus 12 more processes waiting for tasks…
#
# [-        ] NFC…EPARE_GENOME:BWAMEM1_INDEX -
# [-        ] NFC…EPARE_GENOME:BWAMEM2_INDEX -
# [-        ] NFC…E_GENOME:DRAGMAP_HASHTABLE -
# [-        ] NFC…4_CREATESEQUENCEDICTIONARY -
# [-        ] NFC…E_GENOME:MSISENSORPRO_SCAN -
# [-        ] NFC…PARE_GENOME:SAMTOOLS_FAIDX -
# [-        ] NFC…TABIX_BCFTOOLS_ANNOTATIONS -
# [-        ] NFC…PREPARE_GENOME:TABIX_DBSNP -
# [-        ] NFC…ME:TABIX_GERMLINE_RESOURCE -
# [-        ] NFC…RE_GENOME:TABIX_KNOWN_SNPS -
# [-        ] NFC…_GENOME:TABIX_KNOWN_INDELS -
# [-        ] NFC…K:PREPARE_GENOME:TABIX_PON -
# [-        ] NFC…RVALS:CREATE_INTERVALS_BED -
# [-        ] NFC…_BGZIPTABIX_INTERVAL_SPLIT -
# [-        ] NFC…ZIPTABIX_INTERVAL_COMBINED -
# [-        ] NFCORE_SAREK:SAREK:BAM_TO_CRAM -
# [-        ] NFC…AM_QC_RECAL:SAMTOOLS_STATS -
# [-        ] NFC…EQC:CRAM_QC_RECAL:MOSDEPTH -
# [-        ] NFC…CHECKMATE:BCFTOOLS_MPILEUP -
# [-        ] NFC…CHECKMATE:NGSCHECKMATE_NCM -
# Plus 13 more processes waiting for tasks…
#
# [-        ] NFC…EPARE_GENOME:BWAMEM1_INDEX -
# [-        ] NFC…EPARE_GENOME:BWAMEM2_INDEX -
# [-        ] NFC…E_GENOME:DRAGMAP_HASHTABLE -
# [-        ] NFC…4_CREATESEQUENCEDICTIONARY -
# [-        ] NFC…E_GENOME:MSISENSORPRO_SCAN -
# [-        ] NFC…PARE_GENOME:SAMTOOLS_FAIDX -
# [-        ] NFC…TABIX_BCFTOOLS_ANNOTATIONS -
# [-        ] NFC…PREPARE_GENOME:TABIX_DBSNP -
# [-        ] NFC…ME:TABIX_GERMLINE_RESOURCE -
# [-        ] NFC…RE_GENOME:TABIX_KNOWN_SNPS -
# [-        ] NFC…_GENOME:TABIX_KNOWN_INDELS -
# [-        ] NFC…K:PREPARE_GENOME:TABIX_PON -
# [-        ] NFC…RVALS:CREATE_INTERVALS_BED -
# [-        ] NFC…_BGZIPTABIX_INTERVAL_SPLIT -
# [-        ] NFC…ZIPTABIX_INTERVAL_COMBINED -
# [-        ] NFCORE_SAREK:SAREK:BAM_TO_CRAM -
# [-        ] NFC…AM_QC_RECAL:SAMTOOLS_STATS -
# [-        ] NFC…EQC:CRAM_QC_RECAL:MOSDEPTH -
# [-        ] NFC…CHECKMATE:BCFTOOLS_MPILEUP -
# [-        ] NFC…CHECKMATE:NGSCHECKMATE_NCM -
# Plus 14 more processes waiting for tasks…
#
# [-        ] NFC…EPARE_GENOME:BWAMEM1_INDEX -
# [-        ] NFC…EPARE_GENOME:BWAMEM2_INDEX -
# [-        ] NFC…E_GENOME:DRAGMAP_HASHTABLE -
# [-        ] NFC…4_CREATESEQUENCEDICTIONARY -
# [-        ] NFC…E_GENOME:MSISENSORPRO_SCAN -
# [-        ] NFC…PARE_GENOME:SAMTOOLS_FAIDX -
# [-        ] NFC…TABIX_BCFTOOLS_ANNOTATIONS -
# [-        ] NFC…PREPARE_GENOME:TABIX_DBSNP -
# [-        ] NFC…ME:TABIX_GERMLINE_RESOURCE -
# [-        ] NFC…RE_GENOME:TABIX_KNOWN_SNPS -
# [-        ] NFC…_GENOME:TABIX_KNOWN_INDELS -
# [-        ] NFC…K:PREPARE_GENOME:TABIX_PON -
# [-        ] NFC…RVALS:CREATE_INTERVALS_BED -
# [-        ] NFC…_BGZIPTABIX_INTERVAL_SPLIT -
# [-        ] NFC…ZIPTABIX_INTERVAL_COMBINED -
# [-        ] NFCORE_SAREK:SAREK:BAM_TO_CRAM -
# [-        ] NFC…AM_QC_RECAL:SAMTOOLS_STATS -
# [-        ] NFC…EQC:CRAM_QC_RECAL:MOSDEPTH -
# [-        ] NFC…CHECKMATE:BCFTOOLS_MPILEUP -
# [-        ] NFC…CHECKMATE:NGSCHECKMATE_NCM -
# Plus 14 more processes waiting for tasks…
#
# [-        ] NFC…EPARE_GENOME:BWAMEM1_INDEX -
# [-        ] NFC…EPARE_GENOME:BWAMEM2_INDEX -
# [-        ] NFC…E_GENOME:DRAGMAP_HASHTABLE -
# [-        ] NFC…4_CREATESEQUENCEDICTIONARY -
# [-        ] NFC…E_GENOME:MSISENSORPRO_SCAN -
# [-        ] NFC…PARE_GENOME:SAMTOOLS_FAIDX -
# [-        ] NFC…TABIX_BCFTOOLS_ANNOTATIONS -
# [-        ] NFC…PREPARE_GENOME:TABIX_DBSNP -
# [-        ] NFC…ME:TABIX_GERMLINE_RESOURCE -
# [-        ] NFC…RE_GENOME:TABIX_KNOWN_SNPS -
# [-        ] NFC…_GENOME:TABIX_KNOWN_INDELS -
# [-        ] NFC…K:PREPARE_GENOME:TABIX_PON -
# [-        ] NFC…RVALS:CREATE_INTERVALS_BED -
# [-        ] NFC…_BGZIPTABIX_INTERVAL_SPLIT -
# [-        ] NFC…ZIPTABIX_INTERVAL_COMBINED -
# [-        ] NFCORE_SAREK:SAREK:BAM_TO_CRAM -
# [-        ] NFC…AM_QC_RECAL:SAMTOOLS_STATS -
# [-        ] NFC…EQC:CRAM_QC_RECAL:MOSDEPTH -
# [-        ] NFC…CHECKMATE:BCFTOOLS_MPILEUP -
# [-        ] NFC…CHECKMATE:NGSCHECKMATE_NCM -
# Plus 14 more processes waiting for tasks…
#
# [-        ] NFC…EPARE_GENOME:BWAMEM1_INDEX -
# [-        ] NFC…EPARE_GENOME:BWAMEM2_INDEX -
# [-        ] NFC…E_GENOME:DRAGMAP_HASHTABLE -
# [-        ] NFC…4_CREATESEQUENCEDICTIONARY -
# [-        ] NFC…E_GENOME:MSISENSORPRO_SCAN -
# [-        ] NFC…PARE_GENOME:SAMTOOLS_FAIDX -
# [-        ] NFC…TABIX_BCFTOOLS_ANNOTATIONS -
# [-        ] NFC…PREPARE_GENOME:TABIX_DBSNP -
# [-        ] NFC…ME:TABIX_GERMLINE_RESOURCE -
# [-        ] NFC…RE_GENOME:TABIX_KNOWN_SNPS -
# [-        ] NFC…_GENOME:TABIX_KNOWN_INDELS -
# [-        ] NFC…K:PREPARE_GENOME:TABIX_PON -
# [-        ] NFC…RVALS:CREATE_INTERVALS_BED -
# [-        ] NFC…_BGZIPTABIX_INTERVAL_SPLIT -
# [-        ] NFC…ZIPTABIX_INTERVAL_COMBINED -
# [-        ] NFCORE_SAREK:SAREK:BAM_TO_CRAM -
# [-        ] NFC…AM_QC_RECAL:SAMTOOLS_STATS -
# [-        ] NFC…EQC:CRAM_QC_RECAL:MOSDEPTH -
# [-        ] NFC…CHECKMATE:BCFTOOLS_MPILEUP -
# [-        ] NFC…CHECKMATE:NGSCHECKMATE_NCM -
# Plus 14 more processes waiting for tasks…
# Creating env using conda: /root/.nextflow/assets/nf-core/sarek/./subworkflows/local/prepare_intervals/../../../modules/local/create_intervals_bed/environment.yml [cache /content/work/conda/gawk-f9b4f646bf1b67e52890543d27cb2f27]
# Creating env using conda: /root/.nextflow/assets/nf-core/sarek/./subworkflows/local/prepare_intervals/../../../modules/nf-core/tabix/bgziptabix/environment.yml [cache /content/work/conda/tabix_bgziptabix-dfc8d54a6df60f3be57e291aa8c9f35d]
# Creating env using conda: /root/.nextflow/assets/nf-core/sarek/./subworkflows/local/prepare_genome/../../../modules/nf-core/gatk4/createsequencedictionary/environment.yml [cache /content/work/conda/gatk4_createsequencedictionary-0b0acf868d1091b651f6887bec60aba8]
#
# [-        ] NFC…EPARE_GENOME:BWAMEM1_INDEX -
# [-        ] NFC…EPARE_GENOME:BWAMEM2_INDEX -
# [-        ] NFC…E_GENOME:DRAGMAP_HASHTABLE -
# [-        ] NFC…4_CREATESEQUENCEDICTIONARY -
# [-        ] NFC…E_GENOME:MSISENSORPRO_SCAN -
# [-        ] NFC…PARE_GENOME:SAMTOOLS_FAIDX -
# [-        ] NFC…TABIX_BCFTOOLS_ANNOTATIONS -
# [-        ] NFC…PREPARE_GENOME:TABIX_DBSNP -
# [-        ] NFC…ME:TABIX_GERMLINE_RESOURCE -
# [-        ] NFC…RE_GENOME:TABIX_KNOWN_SNPS -
# [-        ] NFC…_GENOME:TABIX_KNOWN_INDELS -
# [-        ] NFC…K:PREPARE_GENOME:TABIX_PON -
# [-        ] NFC…RVALS:CREATE_INTERVALS_BED -
# [-        ] NFC…_BGZIPTABIX_INTERVAL_SPLIT -
# [-        ] NFC…ZIPTABIX_INTERVAL_COMBINED -
# [-        ] NFCORE_SAREK:SAREK:BAM_TO_CRAM -
# [-        ] NFC…AM_QC_RECAL:SAMTOOLS_STATS -
# [-        ] NFC…EQC:CRAM_QC_RECAL:MOSDEPTH -
# [-        ] NFC…CHECKMATE:BCFTOOLS_MPILEUP -
# [-        ] NFC…CHECKMATE:NGSCHECKMATE_NCM -
# Plus 14 more processes waiting for tasks…
# Creating env using conda: /root/.nextflow/assets/nf-core/sarek/./subworkflows/local/prepare_intervals/../../../modules/local/create_intervals_bed/environment.yml [cache /content/work/conda/gawk-f9b4f646bf1b67e52890543d27cb2f27]
# Creating env using conda: /root/.nextflow/assets/nf-core/sarek/./subworkflows/local/prepare_intervals/../../../modules/nf-core/tabix/bgziptabix/environment.yml [cache /content/work/conda/tabix_bgziptabix-dfc8d54a6df60f3be57e291aa8c9f35d]
# Creating env using conda: /root/.nextflow/assets/nf-core/sarek/./subworkflows/local/prepare_genome/../../../modules/nf-core/gatk4/createsequencedictionary/environment.yml [cache /content/work/conda/gatk4_createsequencedictionary-0b0acf868d1091b651f6887bec60aba8]
# Creating env using conda: /root/.nextflow/assets/nf-core/sarek/./workflows/sarek/../../modules/nf-core/samtools/convert/environment.yml [cache /content/work/conda/samtools_convert-8f52d31604e2ce6fb6dba9647b8c5539]
#
# [-        ] NFC…EPARE_GENOME:BWAMEM1_INDEX -
# [-        ] NFC…EPARE_GENOME:BWAMEM2_INDEX -
# [-        ] NFC…E_GENOME:DRAGMAP_HASHTABLE -
# [-        ] NFC…4_CREATESEQUENCEDICTIONARY -
# [-        ] NFC…E_GENOME:MSISENSORPRO_SCAN -
# [-        ] NFC…PARE_GENOME:SAMTOOLS_FAIDX -
# [-        ] NFC…TABIX_BCFTOOLS_ANNOTATIONS -
# [-        ] NFC…PREPARE_GENOME:TABIX_DBSNP -
# [-        ] NFC…ME:TABIX_GERMLINE_RESOURCE -
# [-        ] NFC…RE_GENOME:TABIX_KNOWN_SNPS -
# [-        ] NFC…_GENOME:TABIX_KNOWN_INDELS -
# [-        ] NFC…K:PREPARE_GENOME:TABIX_PON -
# [-        ] NFC…RVALS:CREATE_INTERVALS_BED -
# [-        ] NFC…_BGZIPTABIX_INTERVAL_SPLIT -
# [-        ] NFC…ZIPTABIX_INTERVAL_COMBINED | 0 of 1
# [-        ] NFCORE_SAREK:SAREK:BAM_TO_CRAM -
# [-        ] NFC…AM_QC_RECAL:SAMTOOLS_STATS -
# [-        ] NFC…EQC:CRAM_QC_RECAL:MOSDEPTH -
# [-        ] NFC…CHECKMATE:BCFTOOLS_MPILEUP -
# [-        ] NFC…CHECKMATE:NGSCHECKMATE_NCM -
# Plus 14 more processes waiting for tasks…
#
#
#
#
#
# executor >  local (1)
# [-        ] NFC…EPARE_GENOME:BWAMEM1_INDEX -
# [-        ] NFC…EPARE_GENOME:BWAMEM2_INDEX -
# [-        ] NFC…E_GENOME:DRAGMAP_HASHTABLE -
# [-        ] NFC…4_CREATESEQUENCEDICTIONARY -
# [-        ] NFC…E_GENOME:MSISENSORPRO_SCAN -
# [-        ] NFC…PARE_GENOME:SAMTOOLS_FAIDX -
# [-        ] NFC…TABIX_BCFTOOLS_ANNOTATIONS -
# [-        ] NFC…PREPARE_GENOME:TABIX_DBSNP -
# [-        ] NFC…ME:TABIX_GERMLINE_RESOURCE -
# [-        ] NFC…RE_GENOME:TABIX_KNOWN_SNPS -
# [-        ] NFC…_GENOME:TABIX_KNOWN_INDELS -
# [-        ] NFC…K:PREPARE_GENOME:TABIX_PON -
# [-        ] NFC…RVALS:CREATE_INTERVALS_BED -
# [-        ] NFC…_BGZIPTABIX_INTERVAL_SPLIT -
# [6a/b892cd] NFC…X_INTERVAL_COMBINED (tp53) | 0 of 1
# [-        ] NFCORE_SAREK:SAREK:BAM_TO_CRAM -
# [-        ] NFC…AM_QC_RECAL:SAMTOOLS_STATS -
# [-        ] NFC…EQC:CRAM_QC_RECAL:MOSDEPTH -
# [-        ] NFC…CHECKMATE:BCFTOOLS_MPILEUP -
# [-        ] NFC…CHECKMATE:NGSCHECKMATE_NCM -
# Plus 14 more processes waiting for tasks…
#
#
#
#
# executor >  local (1)
# [-        ] NFC…EPARE_GENOME:BWAMEM1_INDEX -
# [-        ] NFC…EPARE_GENOME:BWAMEM2_INDEX -
# [-        ] NFC…E_GENOME:DRAGMAP_HASHTABLE -
# [-        ] NFC…4_CREATESEQUENCEDICTIONARY -
# [-        ] NFC…E_GENOME:MSISENSORPRO_SCAN -
# [-        ] NFC…PARE_GENOME:SAMTOOLS_FAIDX -
# [-        ] NFC…TABIX_BCFTOOLS_ANNOTATIONS -
# [-        ] NFC…PREPARE_GENOME:TABIX_DBSNP -
# [-        ] NFC…ME:TABIX_GERMLINE_RESOURCE -
# [-        ] NFC…RE_GENOME:TABIX_KNOWN_SNPS -
# [-        ] NFC…_GENOME:TABIX_KNOWN_INDELS -
# [-        ] NFC…K:PREPARE_GENOME:TABIX_PON -
# [-        ] NFC…RVALS:CREATE_INTERVALS_BED -
# [-        ] NFC…_BGZIPTABIX_INTERVAL_SPLIT -
# [6a/b892cd] NFC…X_INTERVAL_COMBINED (tp53) | 0 of 1
# [-        ] NFCORE_SAREK:SAREK:BAM_TO_CRAM -
# [-        ] NFC…AM_QC_RECAL:SAMTOOLS_STATS -
# [-        ] NFC…EQC:CRAM_QC_RECAL:MOSDEPTH -
# [-        ] NFC…CHECKMATE:BCFTOOLS_MPILEUP -
# [-        ] NFC…CHECKMATE:NGSCHECKMATE_NCM -
# Plus 14 more processes waiting for tasks…
#
# executor >  local (1)
# [-        ] NFC…EPARE_GENOME:BWAMEM1_INDEX -
# [-        ] NFC…EPARE_GENOME:BWAMEM2_INDEX -
# [-        ] NFC…E_GENOME:DRAGMAP_HASHTABLE -
# [-        ] NFC…4_CREATESEQUENCEDICTIONARY -
# [-        ] NFC…E_GENOME:MSISENSORPRO_SCAN -
# [-        ] NFC…PARE_GENOME:SAMTOOLS_FAIDX -
# [-        ] NFC…TABIX_BCFTOOLS_ANNOTATIONS -
# [-        ] NFC…PREPARE_GENOME:TABIX_DBSNP -
# [-        ] NFC…ME:TABIX_GERMLINE_RESOURCE -
# [-        ] NFC…RE_GENOME:TABIX_KNOWN_SNPS -
# [-        ] NFC…_GENOME:TABIX_KNOWN_INDELS -
# [-        ] NFC…K:PREPARE_GENOME:TABIX_PON -
# [-        ] NFC…RVALS:CREATE_INTERVALS_BED -
# [-        ] NFC…_BGZIPTABIX_INTERVAL_SPLIT -
# [6a/b892cd] NFC…X_INTERVAL_COMBINED (tp53) | 1 of 1 ✔
# [-        ] NFCORE_SAREK:SAREK:BAM_TO_CRAM -
# [-        ] NFC…AM_QC_RECAL:SAMTOOLS_STATS -
# [-        ] NFC…EQC:CRAM_QC_RECAL:MOSDEPTH -
# [-        ] NFC…CHECKMATE:BCFTOOLS_MPILEUP -
# [-        ] NFC…CHECKMATE:NGSCHECKMATE_NCM -
# Plus 14 more processes waiting for tasks…
#
# executor >  local (1)
# [-        ] NFC…EPARE_GENOME:BWAMEM1_INDEX -
# [-        ] NFC…EPARE_GENOME:BWAMEM2_INDEX -
# [-        ] NFC…E_GENOME:DRAGMAP_HASHTABLE -
# [-        ] NFC…4_CREATESEQUENCEDICTIONARY -
# [-        ] NFC…E_GENOME:MSISENSORPRO_SCAN -
# [-        ] NFC…PARE_GENOME:SAMTOOLS_FAIDX -
# [-        ] NFC…TABIX_BCFTOOLS_ANNOTATIONS -
# [-        ] NFC…PREPARE_GENOME:TABIX_DBSNP -
# [-        ] NFC…ME:TABIX_GERMLINE_RESOURCE -
# [-        ] NFC…RE_GENOME:TABIX_KNOWN_SNPS -
# [-        ] NFC…_GENOME:TABIX_KNOWN_INDELS -
# [-        ] NFC…K:PREPARE_GENOME:TABIX_PON -
# [-        ] NFC…RVALS:CREATE_INTERVALS_BED -
# [-        ] NFC…_BGZIPTABIX_INTERVAL_SPLIT -
# [6a/b892cd] NFC…X_INTERVAL_COMBINED (tp53) | 1 of 1 ✔
# [-        ] NFCORE_SAREK:SAREK:BAM_TO_CRAM | 0 of 3
# [-        ] NFC…AM_QC_RECAL:SAMTOOLS_STATS -
# [-        ] NFC…EQC:CRAM_QC_RECAL:MOSDEPTH -
# [-        ] NFC…CHECKMATE:BCFTOOLS_MPILEUP -
# [-        ] NFC…CHECKMATE:NGSCHECKMATE_NCM -
# Plus 14 more processes waiting for tasks…
#
# executor >  local (2)
# [-        ] NFC…EPARE_GENOME:BWAMEM1_INDEX -
# [-        ] NFC…EPARE_GENOME:BWAMEM2_INDEX -
# [-        ] NFC…E_GENOME:DRAGMAP_HASHTABLE -
# [-        ] NFC…4_CREATESEQUENCEDICTIONARY -
# [-        ] NFC…E_GENOME:MSISENSORPRO_SCAN -
# [-        ] NFC…PARE_GENOME:SAMTOOLS_FAIDX -
# [-        ] NFC…TABIX_BCFTOOLS_ANNOTATIONS -
# [-        ] NFC…PREPARE_GENOME:TABIX_DBSNP -
# [-        ] NFC…ME:TABIX_GERMLINE_RESOURCE -
# [-        ] NFC…RE_GENOME:TABIX_KNOWN_SNPS -
# [-        ] NFC…_GENOME:TABIX_KNOWN_INDELS -
# [-        ] NFC…K:PREPARE_GENOME:TABIX_PON -
# [-        ] NFC…RVALS:CREATE_INTERVALS_BED -
# [-        ] NFC…_BGZIPTABIX_INTERVAL_SPLIT -
# [6a/b892cd] NFC…X_INTERVAL_COMBINED (tp53) | 1 of 1 ✔
# [84/a8b56d] NFC…M_TO_CRAM (normal_sample1) | 0 of 4
# [-        ] NFC…AM_QC_RECAL:SAMTOOLS_STATS -
# [-        ] NFC…EQC:CRAM_QC_RECAL:MOSDEPTH -
# [-        ] NFC…CHECKMATE:BCFTOOLS_MPILEUP -
# [-        ] NFC…CHECKMATE:NGSCHECKMATE_NCM -
# Plus 14 more processes waiting for tasks…
#
# executor >  local (3)
# [-        ] NFC…EPARE_GENOME:BWAMEM1_INDEX -
# [-        ] NFC…EPARE_GENOME:BWAMEM2_INDEX -
# [-        ] NFC…E_GENOME:DRAGMAP_HASHTABLE -
# [-        ] NFC…4_CREATESEQUENCEDICTIONARY -
# [-        ] NFC…E_GENOME:MSISENSORPRO_SCAN -
# [-        ] NFC…PARE_GENOME:SAMTOOLS_FAIDX -
# [-        ] NFC…TABIX_BCFTOOLS_ANNOTATIONS -
# [-        ] NFC…PREPARE_GENOME:TABIX_DBSNP -
# [-        ] NFC…ME:TABIX_GERMLINE_RESOURCE -
# [-        ] NFC…RE_GENOME:TABIX_KNOWN_SNPS -
# [-        ] NFC…_GENOME:TABIX_KNOWN_INDELS -
# [-        ] NFC…K:PREPARE_GENOME:TABIX_PON -
# [-        ] NFC…RVALS:CREATE_INTERVALS_BED -
# [-        ] NFC…_BGZIPTABIX_INTERVAL_SPLIT -
# [6a/b892cd] NFC…X_INTERVAL_COMBINED (tp53) | 1 of 1 ✔
# [84/a8b56d] NFC…M_TO_CRAM (normal_sample1) | 1 of 4
# [-        ] NFC…AM_QC_RECAL:SAMTOOLS_STATS -
# [-        ] NFC…EQC:CRAM_QC_RECAL:MOSDEPTH -
# [-        ] NFC…CHECKMATE:BCFTOOLS_MPILEUP -
# [-        ] NFC…CHECKMATE:NGSCHECKMATE_NCM -
# Plus 14 more processes waiting for tasks…
#
# executor >  local (3)
# [-        ] NFC…EPARE_GENOME:BWAMEM1_INDEX -
# [-        ] NFC…EPARE_GENOME:BWAMEM2_INDEX -
# [-        ] NFC…E_GENOME:DRAGMAP_HASHTABLE -
# [-        ] NFC…4_CREATESEQUENCEDICTIONARY -
# [-        ] NFC…E_GENOME:MSISENSORPRO_SCAN -
# [-        ] NFC…PARE_GENOME:SAMTOOLS_FAIDX -
# [-        ] NFC…TABIX_BCFTOOLS_ANNOTATIONS -
# [-        ] NFC…PREPARE_GENOME:TABIX_DBSNP -
# [-        ] NFC…ME:TABIX_GERMLINE_RESOURCE -
# [-        ] NFC…RE_GENOME:TABIX_KNOWN_SNPS -
# [-        ] NFC…_GENOME:TABIX_KNOWN_INDELS -
# [-        ] NFC…K:PREPARE_GENOME:TABIX_PON -
# [-        ] NFC…RVALS:CREATE_INTERVALS_BED -
# [-        ] NFC…_BGZIPTABIX_INTERVAL_SPLIT -
# [6a/b892cd] NFC…X_INTERVAL_COMBINED (tp53) | 1 of 1 ✔
# [84/a8b56d] NFC…M_TO_CRAM (normal_sample1) | 1 of 4
# [-        ] NFC…AM_QC_RECAL:SAMTOOLS_STATS -
# [-        ] NFC…EQC:CRAM_QC_RECAL:MOSDEPTH -
# [-        ] NFC…CHECKMATE:BCFTOOLS_MPILEUP -
# [-        ] NFC…CHECKMATE:NGSCHECKMATE_NCM -
# Plus 14 more processes waiting for tasks…
# Creating env using conda: /root/.nextflow/assets/nf-core/sarek/./workflows/sarek/../../subworkflows/local/cram_sampleqc/../../../subworkflows/local/cram_qc_mosdepth_samtools/../../../modules/nf-core/samtools/stats/environment.yml [cache /content/work/conda/samtools_stats-c133b92de9ff6f2706e303ccc96c75db]
# Creating env using conda: /root/.nextflow/assets/nf-core/sarek/./workflows/sarek/../../subworkflows/local/cram_sampleqc/../../../subworkflows/local/cram_qc_mosdepth_samtools/../../../modules/nf-core/mosdepth/environment.yml [cache /content/work/conda/mosdepth-6cb355b047aae0d382874f67db7bf450]
#
# executor >  local (4)
# [-        ] NFC…EPARE_GENOME:BWAMEM1_INDEX -
# [-        ] NFC…EPARE_GENOME:BWAMEM2_INDEX -
# [-        ] NFC…E_GENOME:DRAGMAP_HASHTABLE -
# [-        ] NFC…4_CREATESEQUENCEDICTIONARY -
# [-        ] NFC…E_GENOME:MSISENSORPRO_SCAN -
# [-        ] NFC…PARE_GENOME:SAMTOOLS_FAIDX -
# [-        ] NFC…TABIX_BCFTOOLS_ANNOTATIONS -
# [-        ] NFC…PREPARE_GENOME:TABIX_DBSNP -
# [-        ] NFC…ME:TABIX_GERMLINE_RESOURCE -
# [-        ] NFC…RE_GENOME:TABIX_KNOWN_SNPS -
# [-        ] NFC…_GENOME:TABIX_KNOWN_INDELS -
# [-        ] NFC…K:PREPARE_GENOME:TABIX_PON -
# [-        ] NFC…RVALS:CREATE_INTERVALS_BED -
# [-        ] NFC…_BGZIPTABIX_INTERVAL_SPLIT -
# [6a/b892cd] NFC…X_INTERVAL_COMBINED (tp53) | 1 of 1 ✔
# [26/de96ee] NFC…AM_TO_CRAM (tumor_sample1) | 2 of 4
# [-        ] NFC…AM_QC_RECAL:SAMTOOLS_STATS -
# [-        ] NFC…EQC:CRAM_QC_RECAL:MOSDEPTH -
# [-        ] NFC…CHECKMATE:BCFTOOLS_MPILEUP -
# [-        ] NFC…CHECKMATE:NGSCHECKMATE_NCM -
# Plus 14 more processes waiting for tasks…
# Creating env using conda: /root/.nextflow/assets/nf-core/sarek/./workflows/sarek/../../subworkflows/local/cram_sampleqc/../../../subworkflows/local/cram_qc_mosdepth_samtools/../../../modules/nf-core/samtools/stats/environment.yml [cache /content/work/conda/samtools_stats-c133b92de9ff6f2706e303ccc96c75db]
# Creating env using conda: /root/.nextflow/assets/nf-core/sarek/./workflows/sarek/../../subworkflows/local/cram_sampleqc/../../../subworkflows/local/cram_qc_mosdepth_samtools/../../../modules/nf-core/mosdepth/environment.yml [cache /content/work/conda/mosdepth-6cb355b047aae0d382874f67db7bf450]
#
# executor >  local (5)
# [-        ] NFC…EPARE_GENOME:BWAMEM1_INDEX -
# [-        ] NFC…EPARE_GENOME:BWAMEM2_INDEX -
# [-        ] NFC…E_GENOME:DRAGMAP_HASHTABLE -
# [-        ] NFC…4_CREATESEQUENCEDICTIONARY -
# [-        ] NFC…E_GENOME:MSISENSORPRO_SCAN -
# [-        ] NFC…PARE_GENOME:SAMTOOLS_FAIDX -
# [-        ] NFC…TABIX_BCFTOOLS_ANNOTATIONS -
# [-        ] NFC…PREPARE_GENOME:TABIX_DBSNP -
# [-        ] NFC…ME:TABIX_GERMLINE_RESOURCE -
# [-        ] NFC…RE_GENOME:TABIX_KNOWN_SNPS -
# [-        ] NFC…_GENOME:TABIX_KNOWN_INDELS -
# [-        ] NFC…K:PREPARE_GENOME:TABIX_PON -
# [-        ] NFC…RVALS:CREATE_INTERVALS_BED -
# [-        ] NFC…_BGZIPTABIX_INTERVAL_SPLIT -
# [6a/b892cd] NFC…X_INTERVAL_COMBINED (tp53) | 1 of 1 ✔
# [27/7a08c9] NFC…AM_TO_CRAM (tumor_sample2) | 3 of 4
# [-        ] NFC…AM_QC_RECAL:SAMTOOLS_STATS -
# [-        ] NFC…EQC:CRAM_QC_RECAL:MOSDEPTH -
# [-        ] NFC…CHECKMATE:BCFTOOLS_MPILEUP -
# [-        ] NFC…CHECKMATE:NGSCHECKMATE_NCM -
# Plus 14 more processes waiting for tasks…
# Creating env using conda: /root/.nextflow/assets/nf-core/sarek/./workflows/sarek/../../subworkflows/local/cram_sampleqc/../../../subworkflows/local/cram_qc_mosdepth_samtools/../../../modules/nf-core/samtools/stats/environment.yml [cache /content/work/conda/samtools_stats-c133b92de9ff6f2706e303ccc96c75db]
# Creating env using conda: /root/.nextflow/assets/nf-core/sarek/./workflows/sarek/../../subworkflows/local/cram_sampleqc/../../../subworkflows/local/cram_qc_mosdepth_samtools/../../../modules/nf-core/mosdepth/environment.yml [cache /content/work/conda/mosdepth-6cb355b047aae0d382874f67db7bf450]
#
# executor >  local (5)
# [-        ] NFC…EPARE_GENOME:BWAMEM1_INDEX -
# [-        ] NFC…EPARE_GENOME:BWAMEM2_INDEX -
# [-        ] NFC…E_GENOME:DRAGMAP_HASHTABLE -
# [-        ] NFC…4_CREATESEQUENCEDICTIONARY -
# [-        ] NFC…E_GENOME:MSISENSORPRO_SCAN -
# [-        ] NFC…PARE_GENOME:SAMTOOLS_FAIDX -
# [-        ] NFC…TABIX_BCFTOOLS_ANNOTATIONS -
# [-        ] NFC…PREPARE_GENOME:TABIX_DBSNP -
# [-        ] NFC…ME:TABIX_GERMLINE_RESOURCE -
# [-        ] NFC…RE_GENOME:TABIX_KNOWN_SNPS -
# [-        ] NFC…_GENOME:TABIX_KNOWN_INDELS -
# [-        ] NFC…K:PREPARE_GENOME:TABIX_PON -
# [-        ] NFC…RVALS:CREATE_INTERVALS_BED -
# [-        ] NFC…_BGZIPTABIX_INTERVAL_SPLIT -
# [6a/b892cd] NFC…X_INTERVAL_COMBINED (tp53) | 1 of 1 ✔
# [ad/277647] NFC…M_TO_CRAM (normal_sample2) | 4 of 4 ✔
# [-        ] NFC…AM_QC_RECAL:SAMTOOLS_STATS -
# [-        ] NFC…EQC:CRAM_QC_RECAL:MOSDEPTH -
# [-        ] NFC…CHECKMATE:BCFTOOLS_MPILEUP -
# [-        ] NFC…CHECKMATE:NGSCHECKMATE_NCM -
# Plus 14 more processes waiting for tasks…
# Creating env using conda: /root/.nextflow/assets/nf-core/sarek/./workflows/sarek/../../subworkflows/local/cram_sampleqc/../../../subworkflows/local/cram_qc_mosdepth_samtools/../../../modules/nf-core/samtools/stats/environment.yml [cache /content/work/conda/samtools_stats-c133b92de9ff6f2706e303ccc96c75db]
# Creating env using conda: /root/.nextflow/assets/nf-core/sarek/./workflows/sarek/../../subworkflows/local/cram_sampleqc/../../../subworkflows/local/cram_qc_mosdepth_samtools/../../../modules/nf-core/mosdepth/environment.yml [cache /content/work/conda/mosdepth-6cb355b047aae0d382874f67db7bf450]
#
# executor >  local (5)
# [-        ] NFC…EPARE_GENOME:BWAMEM1_INDEX -
# [-        ] NFC…EPARE_GENOME:BWAMEM2_INDEX -
# [-        ] NFC…E_GENOME:DRAGMAP_HASHTABLE -
# [-        ] NFC…4_CREATESEQUENCEDICTIONARY | 0 of 1
# [-        ] NFC…E_GENOME:MSISENSORPRO_SCAN -
# [-        ] NFC…PARE_GENOME:SAMTOOLS_FAIDX -
# [-        ] NFC…TABIX_BCFTOOLS_ANNOTATIONS -
# [-        ] NFC…PREPARE_GENOME:TABIX_DBSNP -
# [-        ] NFC…ME:TABIX_GERMLINE_RESOURCE -
# [-        ] NFC…RE_GENOME:TABIX_KNOWN_SNPS -
# [-        ] NFC…_GENOME:TABIX_KNOWN_INDELS -
# [-        ] NFC…K:PREPARE_GENOME:TABIX_PON -
# [-        ] NFC…RVALS:CREATE_INTERVALS_BED -
# [-        ] NFC…_BGZIPTABIX_INTERVAL_SPLIT -
# [6a/b892cd] NFC…X_INTERVAL_COMBINED (tp53) | 1 of 1 ✔
# [ad/277647] NFC…M_TO_CRAM (normal_sample2) | 4 of 4 ✔
# [-        ] NFC…AM_QC_RECAL:SAMTOOLS_STATS -
# [-        ] NFC…EQC:CRAM_QC_RECAL:MOSDEPTH -
# [-        ] NFC…CHECKMATE:BCFTOOLS_MPILEUP -
# [-        ] NFC…CHECKMATE:NGSCHECKMATE_NCM -
# Plus 14 more processes waiting for tasks…
#
#
#
# executor >  local (6)
# [-        ] NFC…EPARE_GENOME:BWAMEM1_INDEX -
# [-        ] NFC…EPARE_GENOME:BWAMEM2_INDEX -
# [-        ] NFC…E_GENOME:DRAGMAP_HASHTABLE -
# [4f/7852b9] NFC…_sapiens_assembly19.fasta) | 0 of 1
# [-        ] NFC…E_GENOME:MSISENSORPRO_SCAN -
# [-        ] NFC…PARE_GENOME:SAMTOOLS_FAIDX -
# [-        ] NFC…TABIX_BCFTOOLS_ANNOTATIONS -
# [-        ] NFC…PREPARE_GENOME:TABIX_DBSNP -
# [-        ] NFC…ME:TABIX_GERMLINE_RESOURCE -
# [-        ] NFC…RE_GENOME:TABIX_KNOWN_SNPS -
# [-        ] NFC…_GENOME:TABIX_KNOWN_INDELS -
# [-        ] NFC…K:PREPARE_GENOME:TABIX_PON -
# [-        ] NFC…RVALS:CREATE_INTERVALS_BED -
# [-        ] NFC…_BGZIPTABIX_INTERVAL_SPLIT -
# [6a/b892cd] NFC…X_INTERVAL_COMBINED (tp53) | 1 of 1 ✔
# [ad/277647] NFC…M_TO_CRAM (normal_sample2) | 4 of 4 ✔
# [-        ] NFC…AM_QC_RECAL:SAMTOOLS_STATS -
# [-        ] NFC…EQC:CRAM_QC_RECAL:MOSDEPTH -
# [-        ] NFC…CHECKMATE:BCFTOOLS_MPILEUP -
# [-        ] NFC…CHECKMATE:NGSCHECKMATE_NCM -
# Plus 14 more processes waiting for tasks…
#
#
#
# executor >  local (6)
# [-        ] NFC…EPARE_GENOME:BWAMEM1_INDEX -
# [-        ] NFC…EPARE_GENOME:BWAMEM2_INDEX -
# [-        ] NFC…E_GENOME:DRAGMAP_HASHTABLE -
# [4f/7852b9] NFC…_sapiens_assembly19.fasta) | 1 of 1 ✔
# [-        ] NFC…E_GENOME:MSISENSORPRO_SCAN -
# [-        ] NFC…PARE_GENOME:SAMTOOLS_FAIDX -
# [-        ] NFC…TABIX_BCFTOOLS_ANNOTATIONS -
# [-        ] NFC…PREPARE_GENOME:TABIX_DBSNP -
# [-        ] NFC…ME:TABIX_GERMLINE_RESOURCE -
# [-        ] NFC…RE_GENOME:TABIX_KNOWN_SNPS -
# [-        ] NFC…_GENOME:TABIX_KNOWN_INDELS -
# [-        ] NFC…K:PREPARE_GENOME:TABIX_PON -
# [-        ] NFC…RVALS:CREATE_INTERVALS_BED -
# [-        ] NFC…_BGZIPTABIX_INTERVAL_SPLIT -
# [6a/b892cd] NFC…X_INTERVAL_COMBINED (tp53) | 1 of 1 ✔
# [ad/277647] NFC…M_TO_CRAM (normal_sample2) | 4 of 4 ✔
# [-        ] NFC…AM_QC_RECAL:SAMTOOLS_STATS -
# [-        ] NFC…EQC:CRAM_QC_RECAL:MOSDEPTH -
# [-        ] NFC…CHECKMATE:BCFTOOLS_MPILEUP -
# [-        ] NFC…CHECKMATE:NGSCHECKMATE_NCM -
# Plus 14 more processes waiting for tasks…
#
# executor >  local (7)
# [-        ] NFC…EPARE_GENOME:BWAMEM1_INDEX -
# [-        ] NFC…EPARE_GENOME:BWAMEM2_INDEX -
# [-        ] NFC…E_GENOME:DRAGMAP_HASHTABLE -
# [4f/7852b9] NFC…_sapiens_assembly19.fasta) | 1 of 1 ✔
# [-        ] NFC…E_GENOME:MSISENSORPRO_SCAN -
# [-        ] NFC…PARE_GENOME:SAMTOOLS_FAIDX -
# [-        ] NFC…TABIX_BCFTOOLS_ANNOTATIONS -
# [-        ] NFC…PREPARE_GENOME:TABIX_DBSNP -
# [-        ] NFC…ME:TABIX_GERMLINE_RESOURCE -
# [-        ] NFC…RE_GENOME:TABIX_KNOWN_SNPS -
# [-        ] NFC…_GENOME:TABIX_KNOWN_INDELS -
# [-        ] NFC…K:PREPARE_GENOME:TABIX_PON -
# [84/c1c675] NFC…E_INTERVALS_BED (tp53.bed) | 0 of 1
# [-        ] NFC…_BGZIPTABIX_INTERVAL_SPLIT -
# [6a/b892cd] NFC…X_INTERVAL_COMBINED (tp53) | 1 of 1 ✔
# [ad/277647] NFC…M_TO_CRAM (normal_sample2) | 4 of 4 ✔
# [-        ] NFC…AM_QC_RECAL:SAMTOOLS_STATS -
# [-        ] NFC…EQC:CRAM_QC_RECAL:MOSDEPTH -
# [-        ] NFC…CHECKMATE:BCFTOOLS_MPILEUP -
# [-        ] NFC…CHECKMATE:NGSCHECKMATE_NCM -
# Plus 14 more processes waiting for tasks…
#
# executor >  local (7)
# [-        ] NFC…EPARE_GENOME:BWAMEM1_INDEX -
# [-        ] NFC…EPARE_GENOME:BWAMEM2_INDEX -
# [-        ] NFC…E_GENOME:DRAGMAP_HASHTABLE -
# [4f/7852b9] NFC…_sapiens_assembly19.fasta) | 1 of 1 ✔
# [-        ] NFC…E_GENOME:MSISENSORPRO_SCAN -
# [-        ] NFC…PARE_GENOME:SAMTOOLS_FAIDX -
# [-        ] NFC…TABIX_BCFTOOLS_ANNOTATIONS -
# [-        ] NFC…PREPARE_GENOME:TABIX_DBSNP -
# [-        ] NFC…ME:TABIX_GERMLINE_RESOURCE -
# [-        ] NFC…RE_GENOME:TABIX_KNOWN_SNPS -
# [-        ] NFC…_GENOME:TABIX_KNOWN_INDELS -
# [-        ] NFC…K:PREPARE_GENOME:TABIX_PON -
# [84/c1c675] NFC…E_INTERVALS_BED (tp53.bed) | 1 of 1 ✔
# [-        ] NFC…_BGZIPTABIX_INTERVAL_SPLIT -
# [6a/b892cd] NFC…X_INTERVAL_COMBINED (tp53) | 1 of 1 ✔
# [ad/277647] NFC…M_TO_CRAM (normal_sample2) | 4 of 4 ✔
# [-        ] NFC…AM_QC_RECAL:SAMTOOLS_STATS -
# [-        ] NFC…EQC:CRAM_QC_RECAL:MOSDEPTH -
# [-        ] NFC…CHECKMATE:BCFTOOLS_MPILEUP -
# [-        ] NFC…CHECKMATE:NGSCHECKMATE_NCM -
# Plus 14 more processes waiting for tasks…
#
# executor >  local (8)
# [-        ] NFC…EPARE_GENOME:BWAMEM1_INDEX -
# [-        ] NFC…EPARE_GENOME:BWAMEM2_INDEX -
# [-        ] NFC…E_GENOME:DRAGMAP_HASHTABLE -
# [4f/7852b9] NFC…_sapiens_assembly19.fasta) | 1 of 1 ✔
# [-        ] NFC…E_GENOME:MSISENSORPRO_SCAN -
# [-        ] NFC…PARE_GENOME:SAMTOOLS_FAIDX -
# [-        ] NFC…TABIX_BCFTOOLS_ANNOTATIONS -
# [-        ] NFC…PREPARE_GENOME:TABIX_DBSNP -
# [-        ] NFC…ME:TABIX_GERMLINE_RESOURCE -
# [-        ] NFC…RE_GENOME:TABIX_KNOWN_SNPS -
# [-        ] NFC…_GENOME:TABIX_KNOWN_INDELS -
# [-        ] NFC…K:PREPARE_GENOME:TABIX_PON -
# [84/c1c675] NFC…E_INTERVALS_BED (tp53.bed) | 1 of 1 ✔
# [71/c59176] NFC…SPLIT (17_7571740-7590808) | 0 of 1
# [6a/b892cd] NFC…X_INTERVAL_COMBINED (tp53) | 1 of 1 ✔
# [ad/277647] NFC…M_TO_CRAM (normal_sample2) | 4 of 4 ✔
# [-        ] NFC…AM_QC_RECAL:SAMTOOLS_STATS -
# [-        ] NFC…EQC:CRAM_QC_RECAL:MOSDEPTH -
# [-        ] NFC…CHECKMATE:BCFTOOLS_MPILEUP -
# [-        ] NFC…CHECKMATE:NGSCHECKMATE_NCM -
# Plus 14 more processes waiting for tasks…
#
# executor >  local (8)
# [-        ] NFC…EPARE_GENOME:BWAMEM1_INDEX -
# [-        ] NFC…EPARE_GENOME:BWAMEM2_INDEX -
# [-        ] NFC…E_GENOME:DRAGMAP_HASHTABLE -
# [4f/7852b9] NFC…_sapiens_assembly19.fasta) | 1 of 1 ✔
# [-        ] NFC…E_GENOME:MSISENSORPRO_SCAN -
# [-        ] NFC…PARE_GENOME:SAMTOOLS_FAIDX -
# [-        ] NFC…TABIX_BCFTOOLS_ANNOTATIONS -
# [-        ] NFC…PREPARE_GENOME:TABIX_DBSNP -
# [-        ] NFC…ME:TABIX_GERMLINE_RESOURCE -
# [-        ] NFC…RE_GENOME:TABIX_KNOWN_SNPS -
# [-        ] NFC…_GENOME:TABIX_KNOWN_INDELS -
# [-        ] NFC…K:PREPARE_GENOME:TABIX_PON -
# [84/c1c675] NFC…E_INTERVALS_BED (tp53.bed) | 1 of 1 ✔
# [71/c59176] NFC…SPLIT (17_7571740-7590808) | 1 of 1
# [6a/b892cd] NFC…X_INTERVAL_COMBINED (tp53) | 1 of 1 ✔
# [ad/277647] NFC…M_TO_CRAM (normal_sample2) | 4 of 4 ✔
# [-        ] NFC…AM_QC_RECAL:SAMTOOLS_STATS -
# [-        ] NFC…EQC:CRAM_QC_RECAL:MOSDEPTH -
# [-        ] NFC…CHECKMATE:BCFTOOLS_MPILEUP -
# [-        ] NFC…CHECKMATE:NGSCHECKMATE_NCM -
# Plus 14 more processes waiting for tasks…
#
# executor >  local (8)
# [-        ] NFC…EPARE_GENOME:BWAMEM1_INDEX -
# [-        ] NFC…EPARE_GENOME:BWAMEM2_INDEX -
# [-        ] NFC…E_GENOME:DRAGMAP_HASHTABLE -
# [4f/7852b9] NFC…_sapiens_assembly19.fasta) | 1 of 1 ✔
# [-        ] NFC…E_GENOME:MSISENSORPRO_SCAN -
# [-        ] NFC…PARE_GENOME:SAMTOOLS_FAIDX -
# [-        ] NFC…TABIX_BCFTOOLS_ANNOTATIONS -
# [-        ] NFC…PREPARE_GENOME:TABIX_DBSNP -
# [-        ] NFC…ME:TABIX_GERMLINE_RESOURCE -
# [-        ] NFC…RE_GENOME:TABIX_KNOWN_SNPS -
# [-        ] NFC…_GENOME:TABIX_KNOWN_INDELS -
# [-        ] NFC…K:PREPARE_GENOME:TABIX_PON -
# [84/c1c675] NFC…E_INTERVALS_BED (tp53.bed) | 1 of 1 ✔
# [71/c59176] NFC…SPLIT (17_7571740-7590808) | 1 of 1 ✔
# [6a/b892cd] NFC…X_INTERVAL_COMBINED (tp53) | 1 of 1 ✔
# [ad/277647] NFC…M_TO_CRAM (normal_sample2) | 4 of 4 ✔
# [-        ] NFC…AM_QC_RECAL:SAMTOOLS_STATS -
# [-        ] NFC…EQC:CRAM_QC_RECAL:MOSDEPTH -
# [-        ] NFC…CHECKMATE:BCFTOOLS_MPILEUP -
# [-        ] NFC…CHECKMATE:NGSCHECKMATE_NCM -
# Plus 14 more processes waiting for tasks…
#
# executor >  local (8)
# [-        ] NFC…EPARE_GENOME:BWAMEM1_INDEX -
# [-        ] NFC…EPARE_GENOME:BWAMEM2_INDEX -
# [-        ] NFC…E_GENOME:DRAGMAP_HASHTABLE -
# [4f/7852b9] NFC…_sapiens_assembly19.fasta) | 1 of 1 ✔
# [-        ] NFC…E_GENOME:MSISENSORPRO_SCAN -
# [-        ] NFC…PARE_GENOME:SAMTOOLS_FAIDX -
# [-        ] NFC…TABIX_BCFTOOLS_ANNOTATIONS -
# [-        ] NFC…PREPARE_GENOME:TABIX_DBSNP -
# [-        ] NFC…ME:TABIX_GERMLINE_RESOURCE -
# [-        ] NFC…RE_GENOME:TABIX_KNOWN_SNPS -
# [-        ] NFC…_GENOME:TABIX_KNOWN_INDELS -
# [-        ] NFC…K:PREPARE_GENOME:TABIX_PON -
# [84/c1c675] NFC…E_INTERVALS_BED (tp53.bed) | 1 of 1 ✔
# [71/c59176] NFC…SPLIT (17_7571740-7590808) | 1 of 1 ✔
# ...
# [-        ] NFC…EPARE_GENOME:BWAMEM1_INDEX -
# [-        ] NFC…EPARE_GENOME:BWAMEM2_INDEX -
# [-        ] NFC…E_GENOME:DRAGMAP_HASHTABLE -
# [4f/7852b9] NFC…_sapiens_assembly19.fasta) | 1 of 1 ✔
# [-        ] NFC…E_GENOME:MSISENSORPRO_SCAN -
# [-        ] NFC…PARE_GENOME:SAMTOOLS_FAIDX -
# [-        ] NFC…TABIX_BCFTOOLS_ANNOTATIONS -
# [-        ] NFC…PREPARE_GENOME:TABIX_DBSNP -
# [-        ] NFC…ME:TABIX_GERMLINE_RESOURCE -
# [-        ] NFC…RE_GENOME:TABIX_KNOWN_SNPS -
# [-        ] NFC…_GENOME:TABIX_KNOWN_INDELS -
# [-        ] NFC…K:PREPARE_GENOME:TABIX_PON -
# [84/c1c675] NFC…E_INTERVALS_BED (tp53.bed) | 1 of 1 ✔
# [71/c59176] NFC…SPLIT (17_7571740-7590808) | 1 of 1 ✔
# [6a/b892cd] NFC…X_INTERVAL_COMBINED (tp53) | 1 of 1 ✔
# [ad/277647] NFC…M_TO_CRAM (normal_sample2) | 4 of 4 ✔
# [5c/0d3565] NFC…OLS_STATS (normal_sample2) | 4 of 4 ✔
# [ca/1f03be] NFC…L:MOSDEPTH (tumor_sample2) | 4 of 4 ✔
# [-        ] NFC…CHECKMATE:BCFTOOLS_MPILEUP -
# [-        ] NFC…CHECKMATE:NGSCHECKMATE_NCM -
# [47/dee206] NFC…sample1_vs_normal_sample1) | 2 of 2 ✔
# [5f/721b85] NFC…sample1_vs_normal_sample1) | 4 of 4 ✔
# [5f/006965] NFC…sample1_vs_normal_sample1) | 4 of 4 ✔
# [89/b50ead] NFC…sample1_vs_normal_sample1) | 3 of 4
# Plus 10 more processes waiting for tasks…
#
# executor >  local (30)
# [-        ] NFC…EPARE_GENOME:BWAMEM1_INDEX -
# [-        ] NFC…EPARE_GENOME:BWAMEM2_INDEX -
# [-        ] NFC…E_GENOME:DRAGMAP_HASHTABLE -
# [4f/7852b9] NFC…_sapiens_assembly19.fasta) | 1 of 1 ✔
# [-        ] NFC…E_GENOME:MSISENSORPRO_SCAN -
# [-        ] NFC…PARE_GENOME:SAMTOOLS_FAIDX -
# [-        ] NFC…TABIX_BCFTOOLS_ANNOTATIONS -
# [-        ] NFC…PREPARE_GENOME:TABIX_DBSNP -
# [-        ] NFC…ME:TABIX_GERMLINE_RESOURCE -
# [-        ] NFC…RE_GENOME:TABIX_KNOWN_SNPS -
# [-        ] NFC…_GENOME:TABIX_KNOWN_INDELS -
# [-        ] NFC…K:PREPARE_GENOME:TABIX_PON -
# [84/c1c675] NFC…E_INTERVALS_BED (tp53.bed) | 1 of 1 ✔
# [71/c59176] NFC…SPLIT (17_7571740-7590808) | 1 of 1 ✔
# [6a/b892cd] NFC…X_INTERVAL_COMBINED (tp53) | 1 of 1 ✔
# [ad/277647] NFC…M_TO_CRAM (normal_sample2) | 4 of 4 ✔
# [5c/0d3565] NFC…OLS_STATS (normal_sample2) | 4 of 4 ✔
# [ca/1f03be] NFC…L:MOSDEPTH (tumor_sample2) | 4 of 4 ✔
# [-        ] NFC…CHECKMATE:BCFTOOLS_MPILEUP -
# [-        ] NFC…CHECKMATE:NGSCHECKMATE_NCM -
# [47/dee206] NFC…sample1_vs_normal_sample1) | 2 of 2 ✔
# [5f/721b85] NFC…sample1_vs_normal_sample1) | 4 of 4 ✔
# [5f/006965] NFC…sample1_vs_normal_sample1) | 4 of 4 ✔
# [dd/b855fe] NFC…sample1_vs_normal_sample1) | 4 of 4 ✔
# Plus 10 more processes waiting for tasks…
#
# executor >  local (30)
# [-        ] NFC…EPARE_GENOME:BWAMEM1_INDEX -
# [-        ] NFC…EPARE_GENOME:BWAMEM2_INDEX -
# [-        ] NFC…E_GENOME:DRAGMAP_HASHTABLE -
# [4f/7852b9] NFC…_sapiens_assembly19.fasta) | 1 of 1 ✔
# [-        ] NFC…E_GENOME:MSISENSORPRO_SCAN -
# [-        ] NFC…PARE_GENOME:SAMTOOLS_FAIDX -
# [-        ] NFC…TABIX_BCFTOOLS_ANNOTATIONS -
# [-        ] NFC…PREPARE_GENOME:TABIX_DBSNP -
# [-        ] NFC…ME:TABIX_GERMLINE_RESOURCE -
# [-        ] NFC…RE_GENOME:TABIX_KNOWN_SNPS -
# [-        ] NFC…_GENOME:TABIX_KNOWN_INDELS -
# [-        ] NFC…K:PREPARE_GENOME:TABIX_PON -
# [84/c1c675] NFC…E_INTERVALS_BED (tp53.bed) | 1 of 1 ✔
# [71/c59176] NFC…SPLIT (17_7571740-7590808) | 1 of 1 ✔
# [6a/b892cd] NFC…X_INTERVAL_COMBINED (tp53) | 1 of 1 ✔
# [ad/277647] NFC…M_TO_CRAM (normal_sample2) | 4 of 4 ✔
# [5c/0d3565] NFC…OLS_STATS (normal_sample2) | 4 of 4 ✔
# [ca/1f03be] NFC…L:MOSDEPTH (tumor_sample2) | 4 of 4 ✔
# [-        ] NFC…CHECKMATE:BCFTOOLS_MPILEUP -
# [-        ] NFC…CHECKMATE:NGSCHECKMATE_NCM -
# [47/dee206] NFC…sample1_vs_normal_sample1) | 2 of 2 ✔
# [-        ] NFC…LS_VCFTOOLS:BCFTOOLS_STATS | 0 of 2
# [5f/721b85] NFC…sample1_vs_normal_sample1) | 4 of 4 ✔
# [5f/006965] NFC…sample1_vs_normal_sample1) | 4 of 4 ✔
# [dd/b855fe] NFC…sample1_vs_normal_sample1) | 4 of 4 ✔
# Plus 9 more processes waiting for tasks…
#
# executor >  local (32)
# [-        ] NFC…EPARE_GENOME:BWAMEM1_INDEX -
# [-        ] NFC…EPARE_GENOME:BWAMEM2_INDEX -
# [-        ] NFC…E_GENOME:DRAGMAP_HASHTABLE -
# [4f/7852b9] NFC…_sapiens_assembly19.fasta) | 1 of 1 ✔
# [-        ] NFC…E_GENOME:MSISENSORPRO_SCAN -
# [-        ] NFC…PARE_GENOME:SAMTOOLS_FAIDX -
# [-        ] NFC…TABIX_BCFTOOLS_ANNOTATIONS -
# [-        ] NFC…PREPARE_GENOME:TABIX_DBSNP -
# [-        ] NFC…ME:TABIX_GERMLINE_RESOURCE -
# [-        ] NFC…RE_GENOME:TABIX_KNOWN_SNPS -
# [-        ] NFC…_GENOME:TABIX_KNOWN_INDELS -
# [-        ] NFC…K:PREPARE_GENOME:TABIX_PON -
# [84/c1c675] NFC…E_INTERVALS_BED (tp53.bed) | 1 of 1 ✔
# [71/c59176] NFC…SPLIT (17_7571740-7590808) | 1 of 1 ✔
# [6a/b892cd] NFC…X_INTERVAL_COMBINED (tp53) | 1 of 1 ✔
# [ad/277647] NFC…M_TO_CRAM (normal_sample2) | 4 of 4 ✔
# [5c/0d3565] NFC…OLS_STATS (normal_sample2) | 4 of 4 ✔
# [ca/1f03be] NFC…L:MOSDEPTH (tumor_sample2) | 4 of 4 ✔
# [-        ] NFC…CHECKMATE:BCFTOOLS_MPILEUP -
# [-        ] NFC…CHECKMATE:NGSCHECKMATE_NCM -
# [47/dee206] NFC…sample1_vs_normal_sample1) | 2 of 2 ✔
# [4c/5311ea] NFC…sample2_vs_normal_sample2) | 0 of 4
# [5f/721b85] NFC…sample1_vs_normal_sample1) | 4 of 4 ✔
# [5f/006965] NFC…sample1_vs_normal_sample1) | 4 of 4 ✔
# [dd/b855fe] NFC…sample1_vs_normal_sample1) | 4 of 4 ✔
# Plus 9 more processes waiting for tasks…
#
# executor >  local (33)
# [-        ] NFC…EPARE_GENOME:BWAMEM1_INDEX -
# [-        ] NFC…EPARE_GENOME:BWAMEM2_INDEX -
# [-        ] NFC…E_GENOME:DRAGMAP_HASHTABLE -
# [4f/7852b9] NFC…_sapiens_assembly19.fasta) | 1 of 1 ✔
# [-        ] NFC…E_GENOME:MSISENSORPRO_SCAN -
# [-        ] NFC…PARE_GENOME:SAMTOOLS_FAIDX -
# [-        ] NFC…TABIX_BCFTOOLS_ANNOTATIONS -
# [-        ] NFC…PREPARE_GENOME:TABIX_DBSNP -
# [-        ] NFC…ME:TABIX_GERMLINE_RESOURCE -
# [-        ] NFC…RE_GENOME:TABIX_KNOWN_SNPS -
# [-        ] NFC…_GENOME:TABIX_KNOWN_INDELS -
# [-        ] NFC…K:PREPARE_GENOME:TABIX_PON -
# [84/c1c675] NFC…E_INTERVALS_BED (tp53.bed) | 1 of 1 ✔
# [71/c59176] NFC…SPLIT (17_7571740-7590808) | 1 of 1 ✔
# [6a/b892cd] NFC…X_INTERVAL_COMBINED (tp53) | 1 of 1 ✔
# [ad/277647] NFC…M_TO_CRAM (normal_sample2) | 4 of 4 ✔
# [5c/0d3565] NFC…OLS_STATS (normal_sample2) | 4 of 4 ✔
# [ca/1f03be] NFC…L:MOSDEPTH (tumor_sample2) | 4 of 4 ✔
# [-        ] NFC…CHECKMATE:BCFTOOLS_MPILEUP -
# [-        ] NFC…CHECKMATE:NGSCHECKMATE_NCM -
# [47/dee206] NFC…sample1_vs_normal_sample1) | 2 of 2 ✔
# [e9/2535cc] NFC…sample2_vs_normal_sample2) | 1 of 4
# [5f/721b85] NFC…sample1_vs_normal_sample1) | 4 of 4 ✔
# [5f/006965] NFC…sample1_vs_normal_sample1) | 4 of 4 ✔
# [dd/b855fe] NFC…sample1_vs_normal_sample1) | 4 of 4 ✔
# Plus 9 more processes waiting for tasks…
#
# executor >  local (34)
# [-        ] NFC…EPARE_GENOME:BWAMEM1_INDEX -
# [-        ] NFC…EPARE_GENOME:BWAMEM2_INDEX -
# [-        ] NFC…E_GENOME:DRAGMAP_HASHTABLE -
# [4f/7852b9] NFC…_sapiens_assembly19.fasta) | 1 of 1 ✔
# [-        ] NFC…E_GENOME:MSISENSORPRO_SCAN -
# [-        ] NFC…PARE_GENOME:SAMTOOLS_FAIDX -
# [-        ] NFC…TABIX_BCFTOOLS_ANNOTATIONS -
# [-        ] NFC…PREPARE_GENOME:TABIX_DBSNP -
# [-        ] NFC…ME:TABIX_GERMLINE_RESOURCE -
# [-        ] NFC…RE_GENOME:TABIX_KNOWN_SNPS -
# [-        ] NFC…_GENOME:TABIX_KNOWN_INDELS -
# [-        ] NFC…K:PREPARE_GENOME:TABIX_PON -
# [84/c1c675] NFC…E_INTERVALS_BED (tp53.bed) | 1 of 1 ✔
# [71/c59176] NFC…SPLIT (17_7571740-7590808) | 1 of 1 ✔
# [6a/b892cd] NFC…X_INTERVAL_COMBINED (tp53) | 1 of 1 ✔
# [ad/277647] NFC…M_TO_CRAM (normal_sample2) | 4 of 4 ✔
# [5c/0d3565] NFC…OLS_STATS (normal_sample2) | 4 of 4 ✔
# [ca/1f03be] NFC…L:MOSDEPTH (tumor_sample2) | 4 of 4 ✔
# [-        ] NFC…CHECKMATE:BCFTOOLS_MPILEUP -
# [-        ] NFC…CHECKMATE:NGSCHECKMATE_NCM -
# [47/dee206] NFC…sample1_vs_normal_sample1) | 2 of 2 ✔
# [74/52166e] NFC…sample1_vs_normal_sample1) | 2 of 4
# [5f/721b85] NFC…sample1_vs_normal_sample1) | 4 of 4 ✔
# [5f/006965] NFC…sample1_vs_normal_sample1) | 4 of 4 ✔
# [dd/b855fe] NFC…sample1_vs_normal_sample1) | 4 of 4 ✔
# Plus 9 more processes waiting for tasks…
#
# executor >  local (34)
# [-        ] NFC…EPARE_GENOME:BWAMEM1_INDEX -
# [-        ] NFC…EPARE_GENOME:BWAMEM2_INDEX -
# [-        ] NFC…E_GENOME:DRAGMAP_HASHTABLE -
# [4f/7852b9] NFC…_sapiens_assembly19.fasta) | 1 of 1 ✔
# [-        ] NFC…E_GENOME:MSISENSORPRO_SCAN -
# [-        ] NFC…PARE_GENOME:SAMTOOLS_FAIDX -
# [-        ] NFC…TABIX_BCFTOOLS_ANNOTATIONS -
# [-        ] NFC…PREPARE_GENOME:TABIX_DBSNP -
# [-        ] NFC…ME:TABIX_GERMLINE_RESOURCE -
# [-        ] NFC…RE_GENOME:TABIX_KNOWN_SNPS -
# [-        ] NFC…_GENOME:TABIX_KNOWN_INDELS -
# [-        ] NFC…K:PREPARE_GENOME:TABIX_PON -
# [84/c1c675] NFC…E_INTERVALS_BED (tp53.bed) | 1 of 1 ✔
# [71/c59176] NFC…SPLIT (17_7571740-7590808) | 1 of 1 ✔
# [6a/b892cd] NFC…X_INTERVAL_COMBINED (tp53) | 1 of 1 ✔
# [ad/277647] NFC…M_TO_CRAM (normal_sample2) | 4 of 4 ✔
# [5c/0d3565] NFC…OLS_STATS (normal_sample2) | 4 of 4 ✔
# [ca/1f03be] NFC…L:MOSDEPTH (tumor_sample2) | 4 of 4 ✔
# [-        ] NFC…CHECKMATE:BCFTOOLS_MPILEUP -
# [-        ] NFC…CHECKMATE:NGSCHECKMATE_NCM -
# [47/dee206] NFC…sample1_vs_normal_sample1) | 2 of 2 ✔
# [ef/9c59bb] NFC…sample1_vs_normal_sample1) | 3 of 4
# [5f/721b85] NFC…sample1_vs_normal_sample1) | 4 of 4 ✔
# [5f/006965] NFC…sample1_vs_normal_sample1) | 4 of 4 ✔
# [dd/b855fe] NFC…sample1_vs_normal_sample1) | 4 of 4 ✔
# Plus 9 more processes waiting for tasks…
#
# executor >  local (34)
# [-        ] NFC…EPARE_GENOME:BWAMEM1_INDEX -
# [-        ] NFC…EPARE_GENOME:BWAMEM2_INDEX -
# [-        ] NFC…E_GENOME:DRAGMAP_HASHTABLE -
# [4f/7852b9] NFC…_sapiens_assembly19.fasta) | 1 of 1 ✔
# [-        ] NFC…E_GENOME:MSISENSORPRO_SCAN -
# [-        ] NFC…PARE_GENOME:SAMTOOLS_FAIDX -
# [-        ] NFC…TABIX_BCFTOOLS_ANNOTATIONS -
# [-        ] NFC…PREPARE_GENOME:TABIX_DBSNP -
# [-        ] NFC…ME:TABIX_GERMLINE_RESOURCE -
# [-        ] NFC…RE_GENOME:TABIX_KNOWN_SNPS -
# [-        ] NFC…_GENOME:TABIX_KNOWN_INDELS -
# [-        ] NFC…K:PREPARE_GENOME:TABIX_PON -
# [84/c1c675] NFC…E_INTERVALS_BED (tp53.bed) | 1 of 1 ✔
# [71/c59176] NFC…SPLIT (17_7571740-7590808) | 1 of 1 ✔
# [6a/b892cd] NFC…X_INTERVAL_COMBINED (tp53) | 1 of 1 ✔
# [ad/277647] NFC…M_TO_CRAM (normal_sample2) | 4 of 4 ✔
# [5c/0d3565] NFC…OLS_STATS (normal_sample2) | 4 of 4 ✔
# [ca/1f03be] NFC…L:MOSDEPTH (tumor_sample2) | 4 of 4 ✔
# [-        ] NFC…CHECKMATE:BCFTOOLS_MPILEUP -
# [-        ] NFC…CHECKMATE:NGSCHECKMATE_NCM -
# [47/dee206] NFC…sample1_vs_normal_sample1) | 2 of 2 ✔
# [74/52166e] NFC…sample1_vs_normal_sample1) | 4 of 4 ✔
# [5f/721b85] NFC…sample1_vs_normal_sample1) | 4 of 4 ✔
# [5f/006965] NFC…sample1_vs_normal_sample1) | 4 of 4 ✔
# [dd/b855fe] NFC…sample1_vs_normal_sample1) | 4 of 4 ✔
# Plus 9 more processes waiting for tasks…
#
# executor >  local (34)
# [-        ] NFC…EPARE_GENOME:BWAMEM1_INDEX -
# [-        ] NFC…EPARE_GENOME:BWAMEM2_INDEX -
# [-        ] NFC…E_GENOME:DRAGMAP_HASHTABLE -
# [4f/7852b9] NFC…_sapiens_assembly19.fasta) | 1 of 1 ✔
# [-        ] NFC…E_GENOME:MSISENSORPRO_SCAN -
# [-        ] NFC…PARE_GENOME:SAMTOOLS_FAIDX -
# [-        ] NFC…TABIX_BCFTOOLS_ANNOTATIONS -
# [-        ] NFC…PREPARE_GENOME:TABIX_DBSNP -
# [-        ] NFC…ME:TABIX_GERMLINE_RESOURCE -
# [-        ] NFC…RE_GENOME:TABIX_KNOWN_SNPS -
# [-        ] NFC…_GENOME:TABIX_KNOWN_INDELS -
# [-        ] NFC…K:PREPARE_GENOME:TABIX_PON -
# [84/c1c675] NFC…E_INTERVALS_BED (tp53.bed) | 1 of 1 ✔
# [71/c59176] NFC…SPLIT (17_7571740-7590808) | 1 of 1 ✔
# [6a/b892cd] NFC…X_INTERVAL_COMBINED (tp53) | 1 of 1 ✔
# [ad/277647] NFC…M_TO_CRAM (normal_sample2) | 4 of 4 ✔
# [5c/0d3565] NFC…OLS_STATS (normal_sample2) | 4 of 4 ✔
# [ca/1f03be] NFC…L:MOSDEPTH (tumor_sample2) | 4 of 4 ✔
# [-        ] NFC…CHECKMATE:BCFTOOLS_MPILEUP -
# [-        ] NFC…CHECKMATE:NGSCHECKMATE_NCM -
# [47/dee206] NFC…sample1_vs_normal_sample1) | 2 of 2 ✔
# [74/52166e] NFC…sample1_vs_normal_sample1) | 4 of 4 ✔
# [5f/721b85] NFC…sample1_vs_normal_sample1) | 4 of 4 ✔
# [5f/006965] NFC…sample1_vs_normal_sample1) | 4 of 4 ✔
# [dd/b855fe] NFC…sample1_vs_normal_sample1) | 4 of 4 ✔
# Plus 9 more processes waiting for tasks…
# Creating env using conda: /root/.nextflow/assets/nf-core/sarek/./workflows/sarek/../../modules/nf-core/multiqc/environment.yml [cache /content/work/conda/multiqc-3c79c19229373363894cae5853672dde]
#
# executor >  local (35)
# [-        ] NFC…EPARE_GENOME:BWAMEM1_INDEX -
# [-        ] NFC…EPARE_GENOME:BWAMEM2_INDEX -
# [-        ] NFC…E_GENOME:DRAGMAP_HASHTABLE -
# [4f/7852b9] NFC…_sapiens_assembly19.fasta) | 1 of 1 ✔
# [-        ] NFC…E_GENOME:MSISENSORPRO_SCAN -
# [-        ] NFC…PARE_GENOME:SAMTOOLS_FAIDX -
# [-        ] NFC…TABIX_BCFTOOLS_ANNOTATIONS -
# [-        ] NFC…PREPARE_GENOME:TABIX_DBSNP -
# [-        ] NFC…ME:TABIX_GERMLINE_RESOURCE -
# [-        ] NFC…RE_GENOME:TABIX_KNOWN_SNPS -
# [-        ] NFC…_GENOME:TABIX_KNOWN_INDELS -
# [-        ] NFC…K:PREPARE_GENOME:TABIX_PON -
# [84/c1c675] NFC…E_INTERVALS_BED (tp53.bed) | 1 of 1 ✔
# [71/c59176] NFC…SPLIT (17_7571740-7590808) | 1 of 1 ✔
# [6a/b892cd] NFC…X_INTERVAL_COMBINED (tp53) | 1 of 1 ✔
# [ad/277647] NFC…M_TO_CRAM (normal_sample2) | 4 of 4 ✔
# [5c/0d3565] NFC…OLS_STATS (normal_sample2) | 4 of 4 ✔
# [ca/1f03be] NFC…L:MOSDEPTH (tumor_sample2) | 4 of 4 ✔
# [-        ] NFC…CHECKMATE:BCFTOOLS_MPILEUP -
# [-        ] NFC…CHECKMATE:NGSCHECKMATE_NCM -
# [47/dee206] NFC…sample1_vs_normal_sample1) | 2 of 2 ✔
# [74/52166e] NFC…sample1_vs_normal_sample1) | 4 of 4 ✔
# [5f/721b85] NFC…sample1_vs_normal_sample1) | 4 of 4 ✔
# [5f/006965] NFC…sample1_vs_normal_sample1) | 4 of 4 ✔
# [dd/b855fe] NFC…sample1_vs_normal_sample1) | 4 of 4 ✔
# [d9/4f2e5e] NFCORE_SAREK:SAREK:MULTIQC     | 0 of 1
# Plus 8 more processes waiting for tasks…
#
#
# executor >  local (35)
# [-        ] NFC…EPARE_GENOME:BWAMEM1_INDEX -
# [-        ] NFC…EPARE_GENOME:BWAMEM2_INDEX -
# [-        ] NFC…E_GENOME:DRAGMAP_HASHTABLE -
# [4f/7852b9] NFC…_sapiens_assembly19.fasta) | 1 of 1 ✔
# [-        ] NFC…E_GENOME:MSISENSORPRO_SCAN -
# [-        ] NFC…PARE_GENOME:SAMTOOLS_FAIDX -
# [-        ] NFC…TABIX_BCFTOOLS_ANNOTATIONS -
# [-        ] NFC…PREPARE_GENOME:TABIX_DBSNP -
# [-        ] NFC…ME:TABIX_GERMLINE_RESOURCE -
# [-        ] NFC…RE_GENOME:TABIX_KNOWN_SNPS -
# [-        ] NFC…_GENOME:TABIX_KNOWN_INDELS -
# [-        ] NFC…K:PREPARE_GENOME:TABIX_PON -
# [84/c1c675] NFC…E_INTERVALS_BED (tp53.bed) | 1 of 1 ✔
# [71/c59176] NFC…SPLIT (17_7571740-7590808) | 1 of 1 ✔
# [6a/b892cd] NFC…X_INTERVAL_COMBINED (tp53) | 1 of 1 ✔
# [ad/277647] NFC…M_TO_CRAM (normal_sample2) | 4 of 4 ✔
# [5c/0d3565] NFC…OLS_STATS (normal_sample2) | 4 of 4 ✔
# [ca/1f03be] NFC…L:MOSDEPTH (tumor_sample2) | 4 of 4 ✔
# [-        ] NFC…CHECKMATE:BCFTOOLS_MPILEUP -
# [-        ] NFC…CHECKMATE:NGSCHECKMATE_NCM -
# [47/dee206] NFC…sample1_vs_normal_sample1) | 2 of 2 ✔
# [74/52166e] NFC…sample1_vs_normal_sample1) | 4 of 4 ✔
# [5f/721b85] NFC…sample1_vs_normal_sample1) | 4 of 4 ✔
# [5f/006965] NFC…sample1_vs_normal_sample1) | 4 of 4 ✔
# [dd/b855fe] NFC…sample1_vs_normal_sample1) | 4 of 4 ✔
# [d9/4f2e5e] NFCORE_SAREK:SAREK:MULTIQC     | 1 of 1 ✔
# Plus 8 more processes waiting for tasks…
# -[nf-core/sarek] Pipeline completed successfully-
#
# executor >  local (35)
# [-        ] NFC…EPARE_GENOME:BWAMEM1_INDEX -
# [-        ] NFC…EPARE_GENOME:BWAMEM2_INDEX -
# [-        ] NFC…E_GENOME:DRAGMAP_HASHTABLE -
# [4f/7852b9] NFC…_sapiens_assembly19.fasta) | 1 of 1 ✔
# [-        ] NFC…E_GENOME:MSISENSORPRO_SCAN -
# [-        ] NFC…PARE_GENOME:SAMTOOLS_FAIDX -
# [-        ] NFC…TABIX_BCFTOOLS_ANNOTATIONS -
# [-        ] NFC…PREPARE_GENOME:TABIX_DBSNP -
# [-        ] NFC…ME:TABIX_GERMLINE_RESOURCE -
# [-        ] NFC…RE_GENOME:TABIX_KNOWN_SNPS -
# [-        ] NFC…_GENOME:TABIX_KNOWN_INDELS -
# [-        ] NFC…K:PREPARE_GENOME:TABIX_PON -
# [84/c1c675] NFC…E_INTERVALS_BED (tp53.bed) | 1 of 1 ✔
# [71/c59176] NFC…SPLIT (17_7571740-7590808) | 1 of 1 ✔
# [6a/b892cd] NFC…X_INTERVAL_COMBINED (tp53) | 1 of 1 ✔
# [ad/277647] NFC…M_TO_CRAM (normal_sample2) | 4 of 4 ✔
# [5c/0d3565] NFC…OLS_STATS (normal_sample2) | 4 of 4 ✔
# [ca/1f03be] NFC…L:MOSDEPTH (tumor_sample2) | 4 of 4 ✔
# [-        ] NFC…CHECKMATE:BCFTOOLS_MPILEUP -
# [-        ] NFC…CHECKMATE:NGSCHECKMATE_NCM -
# [47/dee206] NFC…sample1_vs_normal_sample1) | 2 of 2 ✔
# [74/52166e] NFC…sample1_vs_normal_sample1) | 4 of 4 ✔
# [5f/721b85] NFC…sample1_vs_normal_sample1) | 4 of 4 ✔
# [5f/006965] NFC…sample1_vs_normal_sample1) | 4 of 4 ✔
# [dd/b855fe] NFC…sample1_vs_normal_sample1) | 4 of 4 ✔
# [d9/4f2e5e] NFCORE_SAREK:SAREK:MULTIQC     | 1 of 1 ✔
# Plus 8 more processes waiting for tasks…
# -[nf-core/sarek] Pipeline completed successfully-
# Completed at: 25-Jul-2024 17:32:52
# Duration    : 17m 59s
# CPU hours   : 0.2
# Succeeded   : 35

# %%
# %%bash
# zcat ./results/variant_calling/strelka/tumor_sample1_vs_normal_sample1/tumor_sample1_vs_normal_sample1.strelka.somatic_snvs.vcf.gz
# Out:
# ##fileformat=VCFv4.1
# ##fileDate=20240725
# ##source=strelka
# ##source_version=2.9.10
# ##startTime=Thu Jul 25 17:27:49 2024
# ##cmdline=/content/work/conda/strelka_somatic-797e7ecb4792efbff3ce957e697bec25/bin/configureStrelkaSomaticWorkflow.py --tumor tumor_sample1.converted.cram --normal normal_sample1.converted.cram --referenceFasta Homo_sapiens_assembly19.fasta --callRegions 17_7571740-7590808.bed.gz --exome --runDir strelka
# ##reference=file:///content/work/47/dee2062aadb7c94b5a198bc3b6ef82/Homo_sapiens_assembly19.fasta
# ##contig=<ID=1,length=249250621>
# ##contig=<ID=2,length=243199373>
# ##contig=<ID=3,length=198022430>
# ##contig=<ID=4,length=191154276>
# ##contig=<ID=5,length=180915260>
# ##contig=<ID=6,length=171115067>
# ##contig=<ID=7,length=159138663>
# ##contig=<ID=8,length=146364022>
# ##contig=<ID=9,length=141213431>
# ##contig=<ID=10,length=135534747>
# ##contig=<ID=11,length=135006516>
# ##contig=<ID=12,length=133851895>
# ##contig=<ID=13,length=115169878>
# ##contig=<ID=14,length=107349540>
# ##contig=<ID=15,length=102531392>
# ##contig=<ID=16,length=90354753>
# ##contig=<ID=17,length=81195210>
# ##contig=<ID=18,length=78077248>
# ##contig=<ID=19,length=59128983>
# ##contig=<ID=20,length=63025520>
# ##contig=<ID=21,length=48129895>
# ##contig=<ID=22,length=51304566>
# ##contig=<ID=X,length=155270560>
# ##contig=<ID=Y,length=59373566>
# ##contig=<ID=MT,length=16569>
# ##contig=<ID=GL000207.1,length=4262>
# ##contig=<ID=GL000226.1,length=15008>
# ##contig=<ID=GL000229.1,length=19913>
# ##contig=<ID=GL000231.1,length=27386>
# ##contig=<ID=GL000210.1,length=27682>
# ##contig=<ID=GL000239.1,length=33824>
# ##contig=<ID=GL000235.1,length=34474>
# ##contig=<ID=GL000201.1,length=36148>
# ##contig=<ID=GL000247.1,length=36422>
# ##contig=<ID=GL000245.1,length=36651>
# ##contig=<ID=GL000197.1,length=37175>
# ##contig=<ID=GL000203.1,length=37498>
# ##contig=<ID=GL000246.1,length=38154>
# ##contig=<ID=GL000249.1,length=38502>
# ##contig=<ID=GL000196.1,length=38914>
# ##contig=<ID=GL000248.1,length=39786>
# ##contig=<ID=GL000244.1,length=39929>
# ##contig=<ID=GL000238.1,length=39939>
# ##contig=<ID=GL000202.1,length=40103>
# ##contig=<ID=GL000234.1,length=40531>
# ##contig=<ID=GL000232.1,length=40652>
# ##contig=<ID=GL000206.1,length=41001>
# ##contig=<ID=GL000240.1,length=41933>
# ##contig=<ID=GL000236.1,length=41934>
# ##contig=<ID=GL000241.1,length=42152>
# ##contig=<ID=GL000243.1,length=43341>
# ##contig=<ID=GL000242.1,length=43523>
# ##contig=<ID=GL000230.1,length=43691>
# ##contig=<ID=GL000237.1,length=45867>
# ##contig=<ID=GL000233.1,length=45941>
# ##contig=<ID=GL000204.1,length=81310>
# ##contig=<ID=GL000198.1,length=90085>
# ##contig=<ID=GL000208.1,length=92689>
# ##contig=<ID=GL000191.1,length=106433>
# ##contig=<ID=GL000227.1,length=128374>
# ##contig=<ID=GL000228.1,length=129120>
# ##contig=<ID=GL000214.1,length=137718>
# ##contig=<ID=GL000221.1,length=155397>
# ##contig=<ID=GL000209.1,length=159169>
# ##contig=<ID=GL000218.1,length=161147>
# ##contig=<ID=GL000220.1,length=161802>
# ##contig=<ID=GL000213.1,length=164239>
# ##contig=<ID=GL000211.1,length=166566>
# ##contig=<ID=GL000199.1,length=169874>
# ##contig=<ID=GL000217.1,length=172149>
# ##contig=<ID=GL000216.1,length=172294>
# ##contig=<ID=GL000215.1,length=172545>
# ##contig=<ID=GL000205.1,length=174588>
# ##contig=<ID=GL000219.1,length=179198>
# ##contig=<ID=GL000224.1,length=179693>
# ##contig=<ID=GL000223.1,length=180455>
# ##contig=<ID=GL000195.1,length=182896>
# ##contig=<ID=GL000212.1,length=186858>
# ##contig=<ID=GL000222.1,length=186861>
# ##contig=<ID=GL000200.1,length=187035>
# ##contig=<ID=GL000193.1,length=189789>
# ##contig=<ID=GL000194.1,length=191469>
# ##contig=<ID=GL000225.1,length=211173>
# ##contig=<ID=GL000192.1,length=547496>
# ##contig=<ID=NC_007605,length=171823>
# ##content=strelka somatic snv calls
# ##priorSomaticSnvRate=0.0001
# ##INFO=<ID=QSS,Number=1,Type=Integer,Description="Quality score for any somatic snv, ie. for the ALT allele to be present at a significantly different frequency in the tumor and normal">
# ##INFO=<ID=TQSS,Number=1,Type=Integer,Description="Data tier used to compute QSS">
# ##INFO=<ID=NT,Number=1,Type=String,Description="Genotype of the normal in all data tiers, as used to classify somatic variants. One of {ref,het,hom,conflict}.">
# ##INFO=<ID=QSS_NT,Number=1,Type=Integer,Description="Quality score reflecting the joint probability of a somatic variant and NT">
# ##INFO=<ID=TQSS_NT,Number=1,Type=Integer,Description="Data tier used to compute QSS_NT">
# ##INFO=<ID=SGT,Number=1,Type=String,Description="Most likely somatic genotype excluding normal noise states">
# ##INFO=<ID=SOMATIC,Number=0,Type=Flag,Description="Somatic mutation">
# ##INFO=<ID=DP,Number=1,Type=Integer,Description="Combined depth across samples">
# ##INFO=<ID=MQ,Number=1,Type=Float,Description="RMS Mapping Quality">
# ##INFO=<ID=MQ0,Number=1,Type=Integer,Description="Total Mapping Quality Zero Reads">
# ##INFO=<ID=ReadPosRankSum,Number=1,Type=Float,Description="Z-score from Wilcoxon rank sum test of Alt Vs. Ref read-position in the tumor">
# ##INFO=<ID=SNVSB,Number=1,Type=Float,Description="Somatic SNV site strand bias">
# ##INFO=<ID=PNOISE,Number=1,Type=Float,Description="Fraction of panel containing non-reference noise at this site">
# ##INFO=<ID=PNOISE2,Number=1,Type=Float,Description="Fraction of panel containing more than one non-reference noise obs at this site">
# ##INFO=<ID=SomaticEVS,Number=1,Type=Float,Description="Somatic Empirical Variant Score (EVS) expressing the phred-scaled probability of the call being a false positive observation.">
# ##FORMAT=<ID=DP,Number=1,Type=Integer,Description="Read depth for tier1 (used+filtered)">
# ##FORMAT=<ID=FDP,Number=1,Type=Integer,Description="Number of basecalls filtered from original read depth for tier1">
# ##FORMAT=<ID=SDP,Number=1,Type=Integer,Description="Number of reads with deletions spanning this site at tier1">
# ##FORMAT=<ID=SUBDP,Number=1,Type=Integer,Description="Number of reads below tier1 mapping quality threshold aligned across this site">
# ##FORMAT=<ID=AU,Number=2,Type=Integer,Description="Number of 'A' alleles used in tiers 1,2">
# ##FORMAT=<ID=CU,Number=2,Type=Integer,Description="Number of 'C' alleles used in tiers 1,2">
# ##FORMAT=<ID=GU,Number=2,Type=Integer,Description="Number of 'G' alleles used in tiers 1,2">
# ##FORMAT=<ID=TU,Number=2,Type=Integer,Description="Number of 'T' alleles used in tiers 1,2">
# ##FILTER=<ID=LowEVS,Description="Somatic Empirical Variant Score (SomaticEVS) is below threshold">
# ##FILTER=<ID=LowDepth,Description="Tumor or normal sample read depth at this locus is below 2">
# #CHROM	POS	ID	REF	ALT	QUAL	FILTER	INFO	FORMAT	NORMAL	TUMOR
# 17	7572154	.	G	A	.	LowEVS	SOMATIC;QSS=3;TQSS=1;NT=ref;QSS_NT=3;TQSS_NT=1;SGT=AG->AG;DP=42;MQ=46.06;MQ0=15;ReadPosRankSum=-0.38;SNVSB=2.13;SomaticEVS=0.33	DP:FDP:SDP:SUBDP:AU:CU:GU:TU	15:0:2:0:2,2:0,0:13,17:0,0	11:0:0:0:4,4:0,0:7,19:0,0
# 17	7585525	.	C	T	.	LowEVS	SOMATIC;QSS=6;TQSS=2;NT=ref;QSS_NT=6;TQSS_NT=2;SGT=CC->CT;DP=31;MQ=53.33;MQ0=0;ReadPosRankSum=0.73;SNVSB=3.19;SomaticEVS=0.84	DP:FDP:SDP:SUBDP:AU:CU:GU:TU	16:1:0:0:0,0:14,14:0,0:1,3	14:0:0:0:0,0:9,9:0,0:5,5

# %% [markdown]
# ## References
#
# Barnholtz-Sloan, J. S. (2022). Maximizing cancer data-the future of cancer is now. <i>JAMA Oncology</i>. https://doi.org/10.1001/jamaoncol.2022.1572<br/><br/>Corpas, M., Kovalevskaya, N. V., McMurray, A., &#38; Nielsen, F. G. G. (2018). A FAIR guide for data providers to maximise sharing of human genomic data. <i>PLoS Computational Biology</i>, <i>14</i>(3), e1005873. https://doi.org/10.1371/journal.pcbi.1005873<br/><br/>Cuevas-Vicenttín, V., Dey, S., Köhler, S., Riddle, S., &#38; Ludäscher, B. (2012). Scientific Workflows and Provenance: Introduction and Research Opportunities. <i>Datenbank-Spektrum</i>, <i>12</i>(3), 193–203. https://doi.org/10.1007/s13222-012-0100-z<br/><br/>de Visser, C., Johansson, L. F., Kulkarni, P., Mei, H., Neerincx, P., Joeri van der Velde, K., Horvatovich, P., van Gool, A. J., Swertz, M. A., Hoen, P. A. C. ’t, &#38; Niehues, A. (2023). Ten quick tips for building FAIR workflows. <i>PLoS Computational Biology</i>, <i>19</i>(9), e1011369. https://doi.org/10.1371/journal.pcbi.1011369<br/><br/>Goble, C., Cohen-Boulakia, S., Soiland-Reyes, S., Garijo, D., Gil, Y., Crusoe, M. R., Peters, K., &#38; Schober, D. (2020). FAIR computational workflows. <i>Data Intelligence</i>, <i>2</i>(1–2), 108–121. https://doi.org/10.1162/dint_a_00033<br/><br/>Katz, D. S., Gruenpeter, M., &#38; Honeyman, T. (2021). Taking a fresh look at FAIR for research software. <i>Patterns (New York, N.Y.)</i>, <i>2</i>(3), 100222. https://doi.org/10.1016/j.patter.2021.100222<br/><br/>Lamprecht, A.-L., Garcia, L., Kuzak, M., Martinez, C., Arcila, R., Martin Del Pico, E., Dominguez Del Angel, V., Van De Sandt, S., Ison, J., Martinez, P. A., &#38; Others. (2020). Towards FAIR principles for research software. <i>Brown University Digest of Addiction Theory and Application: DATA</i>, <i>3</i>(1), 37–59. https://content.iospress.com/articles/data-science/ds190026<br/><br/>Niu, Y. N., Roberts, E. G., Denisko, D., &#38; Hoffman, M. M. (2022). Assessing and assuring interoperability of a genomics file format. In <i>bioRxiv</i> (p. 2022.01.07.475366). https://doi.org/10.1101/2022.01.07.475366<br/>
